# %%
import pickle
import argparse
import torch
import os
import numpy as np
import torch.optim as optim

# %%
torch.cuda.is_available()
# Out:
# True

# %%
with open('../codes/BFregNN-Cox-for-pyroptosis-in-TNBC/data/ppi_global_graph_0.6.pkl','rb') as f:
        global_graph = pickle.load(f)

# %%
global_graph
# Out:
# {'nodes': {},
#  'ARF5': ['ACAP2',
#   'CD59',
#   'RAB1A',
#   'INS',
#   'TMED3',
#   'COPE',
#   'ACAP1',
#   'COPZ1',
#   'COPZ2',
#   'ANK1',
#   'EXOC7',
#   'ARFGAP3',
#   'ARF1',
#   'COPG1',
#   'ARFIP1',
#   'COPB2',
#   'CD55',
#   'SPTBN2',
#   'KDELR1',
#   'ARCN1',
#   'SURF4',
#   'IQSEC1',
#   'KDELR2',
#   'GORAB',
#   'COPG2',
#   'GGA3',
#   'GIT2',
#   'RABAC1',
#   'ARFIP2',
#   'ANK3',
#   'SPTB',
#   'TMED2',
#   'USO1',
#   'RAB28',
#   'SPTAN1',
#   'SPTBN5',
#   'RAB1B',
#   'GGA1',
#   'SPTBN4',
#   'YKT6',
#   'SPTBN1',
#   'TMED7',
#   'ASAP1',
#   'ARF3',
#   'FOLR1',
#   'GBF1',
#   'ARFGAP2',
#   'RAB11FIP3',
#   'SEC22B',
#   'GCC1',
#   'CYTH1',
#   'AGAP1',
#   'ASAP2',
#   'BET1',
#   'ARFGAP1',
#   'COPA',
#   'KDELR3',
#   'SPTA1',
#   'ARF4',
#   'TMED10',
#   'RAB11A',
#   'TMED9',
#   'RAB11FIP4',
#   'COPB1',
#   'ANK2',
#   'CYTH3'],
#  'M6PR': ['AP2M1',
#   'ARF1',
#   'NSF',
#   'AP1S2',
#   'VTI1A',
#   'PSAP',
#   'IGF2R',
#   'AP1B1',
#   'GLA',
#   'EEA1',
#   'SORT1',
#   'GZMB',
#   'RAB5A',
#   'NAPG',
#   'AP1S3',
#   'TGOLN2',
#   'RAB7B',
#   'VAMP7',
#   'VAMP8',
#   'CTSW',
#   'AP2B1',
#   'RAB9A',
#   'VPS53',
#   'IDUA',
#   'LAMP1',
#   'VAMP4',
#   'RAB7A',
#   'NAGA',
#   'AP2A2',
#   'TFRC',
#   'VPS51',
#   'GNS',
#   'SCARB2',
#   'DNAJC6',
#   'CLTA',
#   'TXNDC5',
#   'GGA1',
#   'CTSB',
#   'GCC2',
#   'CLTC',
#   'DNASE2',
#   'VAMP3',
#   'VPS52',
#   'AP2S1',
#   'RAB9B',
#   'CTSD',
#   'IGF2',
#   'VPS54',
#   'ZFPL1',
#   'DNM2',
#   'WIPI1',
#   'NAPB',
#   'AP2A1',
#   'AP1M1',
#   'VAMP2',
#   'STX16',
#   'REN',
#   'GGA3',
#   'PLIN3',
#   'CTSZ',
#   'GGA2',
#   'OS9',
#   'SH3GL2',
#   'AP1G1',
#   'KIF13A',
#   'AP1M2',
#   'HSPA8',
#   'KIAA1468',
#   'ARRB1',
#   'ERLEC1',
#   'GOLGA2',
#   'CTSF',
#   'RABEPK',
#   'RHOBTB3',
#   'AP1S1',
#   'STX10',
#   'NAPA',
#   'SGSH'],
#  'FKBP4': ['TAPBPL',
#   'HSPA1B',
#   'IRF4',
#   'PWP1',
#   'DYNLL2',
#   'SUGT1',
#   'HSPA2',
#   'MAPK1',
#   'BCL2A1',
#   'ACTR10',
#   'NUP62',
#   'CACYBP',
#   'GNB2L1',
#   'PIK3C2A',
#   'GMPR2',
#   'DCAF11',
#   'DNAJB1',
#   'S100A6',
#   'MYOF',
#   'HSP90AB1',
#   'HSPH1',
#   'IFIT3',
#   'NRIP2',
#   'SERPINB2',
#   'AR',
#   'HSP90AA1',
#   'MAPK3',
#   'DCTN6',
#   'CDK5',
#   'CDC37',
#   'GLMN',
#   'CAPZA2',
#   'GMPR',
#   'HSPA4',
#   'PPP5C',
#   'CAPZA3',
#   'TP53',
#   'CRYL1',
#   'POSTN',
#   'DYNC1LI2',
#   'MTOR',
#   'DCTN2',
#   'HSF1',
#   'PPID',
#   'CAPZA1',
#   'DYNC1I1',
#   'TRPC3',
#   'MAPT',
#   'PTGES3',
#   'PDIA4',
#   'ACTR1A',
#   'SARS',
#   'DYNC1H1',
#   'ESR1',
#   'STIP1',
#   'ATOX1',
#   'PGR',
#   'CHORDC1',
#   'ECI2',
#   'CDC37L1',
#   'CLCA1',
#   'AHSA1',
#   'S100A2',
#   'DCTN5',
#   'HSPA1A',
#   'ATP1B3',
#   'HSPA8',
#   'ESR2',
#   'DCTN1',
#   'DCTN3',
#   'FKBP5',
#   'NR3C2',
#   'NR3C1',
#   'AP4M1',
#   'DCTN4',
#   'DYNC1I2',
#   'CAPZB',
#   'S100A1',
#   'AGO2',
#   'DYNLL1',
#   'PIN1',
#   'DYNC1LI1',
#   'TRPC1',
#   'HSPA1L',
#   'PHYH',
#   'PHLPP1'],
#  'CYP26B1': ['STRA6',
#   'CYP26C1',
#   'CYP2S1',
#   'UGT1A7',
#   'UGT1A5',
#   'CYP2C8',
#   'RARS',
#   'CYP2A6',
#   'CYP2C9',
#   'UGT2B11',
#   'UGT2B4',
#   'UGT2B7',
#   'UGT2B15',
#   'UGT1A6',
#   'UGT1A3',
#   'CYP3A5',
#   'CYP2B6',
#   'CRABP1',
#   'UGT2A2',
#   'UGT2B28',
#   'UGT2B10',
#   'ALDH1A2',
#   'CYP1A2',
#   'ALDH1A1',
#   'NANOS2',
#   'CYP26A1',
#   'STRA8',
#   'UGT1A4',
#   'UGT1A10',
#   'AOX1',
#   'UGT1A9',
#   'UGT1A1',
#   'ALDH1A3',
#   'UGT1A8',
#   'UGT2B17',
#   'CRABP2',
#   'CYP3A4',
#   'CYP1B1',
#   'CYP3A7',
#   'RDH10',
#   'CYP4A11',
#   'CYP4A22',
#   'CYP2C18',
#   'UGT2A3',
#   'CYP1A1'],
#  'NDUFAF7': ['METTL10',
#   'NDUFA6',
#   'TRMT11',
#   'RSAD1',
#   'NDUFB2',
#   'METTL20',
#   'NDUFA3',
#   'NUBPL',
#   'COX6C',
#   'NDUFAF4',
#   'ECSIT',
#   'TFB2M',
#   'NDUFAF6',
#   'TMEM126B',
#   'NDUFS8',
#   'NDUFB11',
#   'NDUFAF5',
#   'MT-ND2',
#   'NDUFAF2',
#   'NDUFA9',
#   'PPOX',
#   'NDUFS2',
#   'MT-ND4',
#   'NDUFS7',
#   'NDUFB8',
#   'MT-ND6',
#   'NDUFA8',
#   'UBE3B',
#   'TIMMDC1',
#   'NDUFB9',
#   'FOXRED1',
#   'NDUFA2',
#   'NDUFAB1',
#   'MT-ND1',
#   'NSUN3',
#   'NDUFA11',
#   'NDUFC1',
#   'NDUFA7',
#   'METTL13',
#   'NDUFS3',
#   'NDUFB7',
#   'ACAD9',
#   'MT-ND3',
#   'MT-ND5',
#   'NDUFB1',
#   'MTRF1L',
#   'NDUFA10',
#   'NDUFA13',
#   'NDUFB5',
#   'NDUFA1',
#   'NDUFAF1',
#   'MTRF1',
#   'COA5',
#   'NDUFC2',
#   'NDUFB6',
#   'NDUFB3',
#   'NDUFB4',
#   'NDUFB10',
#   'NDUFAF3',
#   'NDUFA5'],
#  'FUCA2': ['KRT1',
#   'TXLNB',
#   'CRIP3',
#   'KRT16',
#   'GLB1',
#   'HIVEP2',
#   'FUK',
#   'PLG',
#   'HEXB',
#   'ADAT2',
#   'SNX9',
#   'TGM1',
#   'FPGT',
#   'NAGA',
#   'FUCA1',
#   'HSD11B1',
#   'SLC22A13',
#   'SLC22A23',
#   'HEXA',
#   'NAGLU',
#   'CD99L2',
#   'GLA'],
#  'HS3ST1': ['SDC4',
#   'GPC5',
#   'GPC1',
#   'GPC2',
#   'HS2ST1',
#   'HS6ST3',
#   'HS6ST2',
#   'GPC6',
#   'RAB28',
#   'GPC3',
#   'GLCE',
#   'SDC1',
#   'GCNT3',
#   'SDC3',
#   'SERPINC1',
#   'SDC2',
#   'HS6ST1',
#   'EXT1',
#   'A4GNT',
#   'FUT10',
#   'ENSG00000267561',
#   'UST',
#   'PLEKHG1',
#   'AGRN',
#   'GPC4',
#   'GCNT4',
#   'EXT2',
#   'ARSG',
#   'HSPG2',
#   'EXTL3',
#   'TNS4'],
#  'SEMA3F': ['PLXND1',
#   'PLXNB3',
#   'EPHA6',
#   'PLXNC1',
#   'VEGFA',
#   'PLXNB1',
#   'PLXNB2',
#   'EPHA1',
#   'ROBO2',
#   'NTN1',
#   'SLIT3',
#   'PLXNA3',
#   'PLXNA1',
#   'NRP1',
#   'NRP2'],
#  'CFTR': ['ERLIN2',
#   'PSMD2',
#   'PRKAR1A',
#   'GUCA2A',
#   'ERLIN1',
#   'RPS27A',
#   'SLC9A2',
#   'PSMB6',
#   'UBE2V1',
#   'STX16',
#   'ANO2',
#   'GOPC',
#   'PSMC3',
#   'PSMB10',
#   'HBB',
#   'PRSS58',
#   'DLG4',
#   'SLC4A4',
#   'LPAR2',
#   'BEST2',
#   'GUCY2C',
#   'UBC',
#   'KCNN4',
#   'TSG101',
#   'YAP1',
#   'DYNC1H1',
#   'PSMD12',
#   'STIP1',
#   'SIN3A',
#   'ADCY6',
#   'PSMD6',
#   'BEST1',
#   'SLC4A2',
#   'AGT',
#   'TFRC',
#   'AP2A2',
#   'ATP12A',
#   'ABCG2',
#   'CBL',
#   'ADRB2',
#   'PSMA3',
#   'CANX',
#   'SLC9A3R1',
#   'AP2B1',
#   'PSMF1',
#   'VPS37D',
#   'CHMP4A',
#   'PSMB5',
#   'SRC',
#   'CHMP7',
#   'YWHAB',
#   'DNAJC5',
#   'KCNJ1',
#   'CLCA1',
#   'AHSA1',
#   'VPS37A',
#   'SLC26A6',
#   'CD4',
#   'HSPA1A',
#   'VPS37C',
#   'LAMP2',
#   'VCP',
#   'PSMD1',
#   'ERLEC1',
#   'SNX3',
#   'PSMB8',
#   'HSPA8',
#   'CD3D',
#   'UBE2N',
#   'BEST4',
#   'CXCL12',
#   'RHOQ',
#   'SLC9A3',
#   'PRSS1',
#   'ACTB',
#   'STUB1',
#   'RNF5',
#   'GRASP',
#   'BAG2',
#   'PSMA4',
#   'CCL4',
#   'YWHAG',
#   'SLC26A1',
#   'PRKAB1',
#   'SHANK2',
#   'BEST3',
#   'TSPAN16',
#   'DAB2',
#   'PSMD4',
#   'PRKAB2',
#   'MAP2',
#   'USP10',
#   'CHMP4C',
#   'RAB3B',
#   'PSMB3',
#   'PSMA6',
#   'DYNC1I2',
#   'AHCYL1',
#   'SLC9A3R2',
#   'SNAP23',
#   'PRKACG',
#   'DYNLL1',
#   'CLCNKB',
#   'PSMD13',
#   'SCNN1G',
#   'PSME3',
#   'SCNN1B',
#   'SLC26A5',
#   'SHFM1',
#   'PRKAR2B',
#   'MVB12B',
#   'PRKAG1',
#   'PSMC2',
#   'EDN1',
#   'KCNQ1',
#   'CHMP2B',
#   'SEC61A1',
#   'DYNC1LI1',
#   'PSMA1',
#   'PSMB1',
#   'PRKACA',
#   'CLIC6',
#   'CLCN2',
#   'DERL1',
#   'PSMD9',
#   'CLIC1',
#   'SCNN1A',
#   'PSME2',
#   'YWHAZ',
#   'PDE3B',
#   'PSMD3',
#   'AKAP1',
#   'OS9',
#   'HSPA1B',
#   'PSMB9',
#   'CCL11',
#   'CYP26A1',
#   'MYO5B',
#   'PSMA5',
#   'USH1C',
#   'PSMC4',
#   'AP2A1',
#   'CLIC4',
#   'PRKAA2',
#   'PDZD3',
#   'DERL3',
#   'GFAP',
#   'PSMB7',
#   'PSMB11',
#   'TJP1',
#   'PRKAG3',
#   'CLCN3',
#   'EZR',
#   'TTYH3',
#   'DYNLL2',
#   'AP2S1',
#   'PSMD14',
#   'SEL1L',
#   'CHMP6',
#   'HSPB1',
#   'ANO6',
#   'PRKAG2',
#   'PSMC5',
#   'CHMP2A',
#   'RNF185',
#   'PPP2R1A',
#   'NEDD4L',
#   'PSME1',
#   'PRKAA1',
#   'VPS37B',
#   'CHMP4B',
#   'UBB',
#   'SPINK1',
#   'S100A10',
#   'CLCNKA',
#   'PSMA7',
#   'RAB11A',
#   'CLDN4',
#   'DNAJB1',
#   'PSMD7',
#   'F2',
#   'PSMC1',
#   'HSP90AB1',
#   'KRT18',
#   'TTYH2',
#   'CTRC',
#   'SLC12A1',
#   'PSME4',
#   'PSMD5',
#   'PSMD8',
#   'DERL2',
#   'AP2M1',
#   'AMFR',
#   'PRKACB',
#   'KRT8',
#   'VPS28',
#   'STX1A',
#   'UBAP1',
#   'GNB1',
#   'HSP90AA1',
#   'PSMA2',
#   'FAM101B',
#   'SQSTM1',
#   'CALU',
#   'HKDC1',
#   'SLC12A2',
#   'SLC26A8',
#   'MARCH2',
#   'PSMB2',
#   'CLCN1',
#   'SLC26A3',
#   'PRKAR1B',
#   'PSMD11',
#   'HSPA4',
#   'SLC26A2',
#   'HSPB3',
#   'TRPC6',
#   'IGFBP1',
#   'PARK2',
#   'SLC26A9',
#   'FLNA',
#   'ANO1',
#   'PSMA8',
#   'DNAJA1',
#   'SLC26A4',
#   'MVB12A',
#   'PRKAR2A',
#   'GNGT1',
#   'HDAC6',
#   'PSMD10',
#   'CTNNB1',
#   'PDZK1',
#   'RAB5A',
#   'NEDD4',
#   'SEC24B',
#   'SUMO2',
#   'CXCL8',
#   'DYNC1LI2',
#   'PSMC6',
#   'PSMB4',
#   'HSF1',
#   'SLC4A7',
#   'DYNC1I1',
#   'FKBP8',
#   'PDE3A'],
#  'CYP51A1': ['MVK',
#   'EBP',
#   'LSS',
#   'CYP2C8',
#   'SREBF1',
#   'C14orf1',
#   'ACAT2',
#   'SIGMAR1',
#   'CPOX',
#   'CYP11A1',
#   'MARCH6',
#   'CYP2C19',
#   'SCD',
#   'MVD',
#   'IDI1',
#   'DHCR24',
#   'FDFT1',
#   'ACAT1',
#   'HMGCR',
#   'EGR2',
#   'PRPF19',
#   'SREBF2',
#   'CYB5R3',
#   'FAXDC2',
#   'NFYC',
#   'GGPS1',
#   'AGMO',
#   'SQLE',
#   'NFYA',
#   'PGRMC1',
#   'HMGCS2',
#   'NSDHL',
#   'PGRMC2',
#   'PPIH',
#   'MSMO1',
#   'HSP90AA1',
#   'HSD3B1',
#   'FDPS',
#   'R3HDM4',
#   'TM7SF2',
#   'HSD17B7',
#   'SC5D',
#   'NFYB',
#   'SP1',
#   'DHCR7',
#   'PMVK',
#   'INSIG1',
#   'HMGCS1',
#   'CH25H',
#   'POR',
#   'CYB5A',
#   'PPIG',
#   'LBR'],
#  'USP28': ['USP32',
#   'CLSPN',
#   'TRIM55',
#   'USP29',
#   'USP22',
#   'OTUD6B',
#   'SUMO2',
#   'USP21',
#   'WWP1',
#   'TRIP12',
#   'USP15',
#   'TP53',
#   'UBA52',
#   'RCHY1',
#   'PSMD14',
#   'TP53BP1',
#   'USP11',
#   'ABCC9',
#   'USP12',
#   'USP5',
#   'USP13',
#   'UBB',
#   'UCHL3',
#   'OTUB2',
#   'OTUB1',
#   'USP36',
#   'USP4',
#   'USP33',
#   'FBXW7',
#   'MYC',
#   'USP10',
#   'UCHL5',
#   'USP37',
#   'JOSD1',
#   'UBC',
#   'USP20',
#   'RPS27A',
#   'ZW10',
#   'USP1',
#   'USP2',
#   'TTC12',
#   'STAMBP',
#   'USP8',
#   'USP46',
#   'USP14',
#   'ITCH',
#   'USP19'],
#  'SLC7A2': ['ARG2', 'SLC1A1', 'ARG1', 'RENBP', 'SLC1A7', 'GABRA3', 'SLC1A2'],
#  'PDK4': ['SLC2A4',
#   'DLD',
#   'CPT1A',
#   'ACADM',
#   'UCP3',
#   'CPT1C',
#   'ACOX1',
#   'ANGPTL4',
#   'DLAT',
#   'ESRRA',
#   'PDHA1',
#   'PCK1',
#   'PPARGC1A',
#   'PPARA',
#   'PDK3',
#   'PPARG',
#   'PDHB',
#   'PDHX',
#   'PDHA2',
#   'PDK1',
#   'LTN1',
#   'CPT1B',
#   'PDK2',
#   'INS'],
#  'USH1C': ['CDHR5',
#   'EPS8L3',
#   'CCM2',
#   'SLC4A7',
#   'SAMD4B',
#   'LHFPL5',
#   'TAX1BP3',
#   'MYO15A',
#   'CIB2',
#   'CACNA1D',
#   'MYO7B',
#   'MCOLN1',
#   'CFTR',
#   'OTOG',
#   'PCDH15',
#   'TMC1',
#   'RAP2A',
#   'TMIE',
#   'GPR98',
#   'TAS2R4',
#   'TMPRSS3',
#   'USH1G',
#   'SERGEF',
#   'CDHR2',
#   'MYO3A',
#   'CDHR1',
#   'MCC',
#   'HID1',
#   'OTOF',
#   'USH2A',
#   'CDR2L',
#   'PDZD7',
#   'STRN',
#   'SLC4A8',
#   'VEZT',
#   'LIN7A',
#   'USHBP1',
#   'DFNB31',
#   'PTEN',
#   'CNTN2',
#   'DOCK4',
#   'MYO7A',
#   'ESPN',
#   'PCDH11X',
#   'CLRN1',
#   'MYO1C',
#   'PICK1',
#   'SAAL1',
#   'CDH23',
#   'ANKS4B'],
#  'RALA': ['RPS3',
#   'ARF1',
#   'TUBB4A',
#   'EXOC8',
#   'MAPK13',
#   'MYO5A',
#   'CALM1',
#   'SNAP23',
#   'RAB4A',
#   'RALBP1',
#   'RGL1',
#   'MYH10',
#   'EXOC6',
#   'MAPK9',
#   'VAMP2',
#   'RALGPS1',
#   'RHOQ',
#   'RHOA',
#   'MYH9',
#   'EXOC6B',
#   'EXOC3',
#   'MAPK12',
#   'RTN1',
#   'MSLN',
#   'SYNJ2BP',
#   'EXOC7',
#   'C2CD5',
#   'AKT1',
#   'FKBPL',
#   'RNASE13',
#   'LRPAP1',
#   'SRC',
#   'RGL3',
#   'CDK1',
#   'STXBP3',
#   'RAB14',
#   'EXOC1',
#   'RALGAPB',
#   'YBX3',
#   'PLCD1',
#   'TNFAIP2',
#   'KIF3A',
#   'KIFAP3',
#   'CDKN2A',
#   'CNKSR2',
#   'PLD2',
#   'MAPK11',
#   'MYO1C',
#   'KRAS',
#   'STAT4',
#   'KIF3B',
#   'HRAS',
#   'RALGAPA2',
#   'ARF3',
#   'RAB10',
#   'RAF1',
#   'RAB8A',
#   'RGL4',
#   'CALM3',
#   'EXOC2',
#   'NDUFS6',
#   'RALGDS',
#   'SYT13',
#   'FLNA',
#   'PLD1',
#   'MAPK8',
#   'RGL2',
#   'RAC3',
#   'PPP2R1B',
#   'EPHA4',
#   'STX4',
#   'RALB',
#   'EXOC5',
#   'TBK1',
#   'RAB11A',
#   'RAC2',
#   'MYO1E',
#   'SLC2A4',
#   'BMPER',
#   'CCND1',
#   'REPS2',
#   'REPS1',
#   'RAB13',
#   'RAC1',
#   'MAPK14',
#   'MAPK10',
#   'EXOC4',
#   'ARF6',
#   'ADRBK1',
#   'ASPSCR1',
#   'NRAS'],
#  'BAIAP2L1': ['BAIAP2',
#   'WAS',
#   'EPS8',
#   'NCK1',
#   'MTSS1L',
#   'TACC3',
#   'WASL',
#   'CDC42'],
#  'CACNG3': ['RASGRP3',
#   'CACNA1D',
#   'CACNA1F',
#   'CATSPER4',
#   'RASGRP2',
#   'PRKACG',
#   'PPP2R5D',
#   'RASGRP1',
#   'MDM2',
#   'PPP1CC',
#   'SHISA7',
#   'GRIN3B',
#   'CACNA1S',
#   'CACNG6',
#   'CACNB4',
#   'VWC2',
#   'HTR3A',
#   'PPP2R3C',
#   'CACNA1G',
#   'CACNA2D4',
#   'GRIA2',
#   'GRIA4',
#   'CACNG1',
#   'GRIK2',
#   'PPP2R2A',
#   'PRKACA',
#   'CATSPER1',
#   'OLFM2',
#   'CACNA1C',
#   'CACNA2D2',
#   'GRIK3',
#   'PPP2R2D',
#   'CACNB1',
#   'TEX40',
#   'GRIN2A',
#   'SHISA9',
#   'PRKACB',
#   'GRIN2D',
#   'CATSPERD',
#   'GRIN2C',
#   'SHISA6',
#   'CACNB3',
#   'CATSPER2',
#   'FKBP1A',
#   'PPP2CB',
#   'PPP2R5B',
#   'PPP2R5A',
#   'PPP1CB',
#   'RYR1',
#   'CACNG7',
#   'PPP2R1B',
#   'CACNB2',
#   'GRIA1',
#   'GRIK5',
#   'OPALIN',
#   'PPP2R5E',
#   'PPP2R3A',
#   'CACNA1B',
#   'AKAP5',
#   'MYO6',
#   'PPP2CA',
#   'PPP2R1A',
#   'PPP2R2B',
#   'GRIA3',
#   'EPB41L1',
#   'PPP2R5C',
#   'CACNG2',
#   'CNIH2',
#   'CACNG5',
#   'CATSPERB',
#   'OXTR',
#   'HSPA2',
#   'DLG1',
#   'CACNG8',
#   'VWC2L',
#   'GRIK1',
#   'CACNA2D1',
#   'GRIK4',
#   'C1orf101',
#   'ADAM23',
#   'CAMK2D',
#   'ADAM22',
#   'PPP2R3B',
#   'RASGRF2',
#   'CACNA1A',
#   'RASGRP4',
#   'RASGRF1',
#   'CACNA2D3',
#   'GRIN3A',
#   'CACNA1H',
#   'STAC3',
#   'LGI1',
#   'CACNA1I',
#   'CAMK2B',
#   'GRIN2B',
#   'GRID2',
#   'GRIN1',
#   'CAMK2G',
#   'CNIH3',
#   'PPP2R2C',
#   'PPP1CA',
#   'CAMK2A',
#   'CACNA1E',
#   'DLG4',
#   'CATSPERG',
#   'CATSPER3',
#   'CACNG4'],
#  'TMEM132A': ['MGAT5B', 'SSR3', 'HSD17B2', 'DNAJC12', 'SYNDIG1', 'SYNGR1'],
#  'DVL2': ['CCDC88A',
#   'LRRK2',
#   'FZD5',
#   'AMOTL2',
#   'WNT2',
#   'CUL3',
#   'PI4K2A',
#   'AAK1',
#   'NOTCH2',
#   'UBA52',
#   'AP2A1',
#   'CLTB',
#   'FMN1',
#   'PTK7',
#   'BAMBI',
#   'AXIN1',
#   'LATS1',
#   'AP2S1',
#   'CTHRC1',
#   'WNT3A',
#   'CCDC88C',
#   'NOX1',
#   'REPS1',
#   'CELSR1',
#   'RAC1',
#   'DAAM2',
#   'PPP2R5C',
#   'FCHO2',
#   'MOB1B',
#   'PPP2R1A',
#   'AXIN2',
#   'ITSN2',
#   'WNT9A',
#   'VANGL1',
#   'FRAT1',
#   'PPP2CA',
#   'LRP6',
#   'UBB',
#   'PPP2R5E',
#   'TIAM1',
#   'NECAP2',
#   'TRIM29',
#   'RAC2',
#   'ANKRD6',
#   'CSNK2A3',
#   'AP2M1',
#   'PRICKLE3',
#   'EPN1',
#   'RYK',
#   'FZD10',
#   'JUN',
#   'FZD1',
#   'EPN2',
#   'CSNK1G2',
#   'PIP5K1B',
#   'RAB35',
#   'SQSTM1',
#   'KLHL12',
#   'SMAD3',
#   'WNT9B',
#   'CSNK1D',
#   'OTULIN',
#   'PPP2R1B',
#   'INVS',
#   'WNT1',
#   'DAAM1',
#   'MAPK8',
#   'PPP2R5B',
#   'PPP2CB',
#   'CLTC',
#   'RAC3',
#   'WWTR1',
#   'GNAQ',
#   'DVL1',
#   'WNT5A',
#   'APC2',
#   'FZD2',
#   'OEBT',
#   'LRP5',
#   'WNT4',
#   'PPP2R5D',
#   'TP53',
#   'EPS15',
#   'NKD1',
#   'CTNNB1',
#   'NOXO1',
#   'FZD4',
#   'NKD2',
#   'WNT11',
#   'INTU',
#   'WWP1',
#   'APC',
#   'CLTCL1',
#   'EFNB1',
#   'MAP2K7',
#   'DACT1',
#   'FZD3',
#   'PFN1',
#   'ARRB2',
#   'RPS27A',
#   'ARRB1',
#   'GSK3B',
#   'WNT3',
#   'SMURF1',
#   'FZD9',
#   'PRICKLE2',
#   'PRKCA',
#   'CSNK2B',
#   'UBC',
#   'SGIP1',
#   'NECAP1',
#   'UBQLN2',
#   'RGS3',
#   'ITCH',
#   'PARD6A',
#   'ROR2',
#   'AP2A2',
#   'CSNK2A1',
#   'WNT8B',
#   'IRS1',
#   'SAG',
#   'AP2B1',
#   'FCHO1',
#   'ITSN1',
#   'RBX1',
#   'VHL',
#   'WWP2',
#   'SMURF2',
#   'SENP2',
#   'GSK3A',
#   'WWOX',
#   'PRKCG',
#   'DVL3',
#   'FZD6',
#   'CSNK1A1',
#   'FUZ',
#   'RNF43',
#   'RHOA',
#   'GABARAPL1',
#   'ESR2',
#   'CSNK1E',
#   'CSNK2A2',
#   'NOTCH3',
#   'PPP2R5A',
#   'FZD8',
#   'AMOT',
#   'MOB1A',
#   'FZD7',
#   'VANGL2',
#   'NXN',
#   'CLTA',
#   'MYC',
#   'NOXA1',
#   'CYBA',
#   'WNT5B',
#   'CSNK1G1',
#   'LATS2',
#   'PRKCB',
#   'CXXC4',
#   'DACT2',
#   'FRAT2',
#   'PRICKLE1',
#   'NOTCH1',
#   'PLK1',
#   'WNT8A',
#   'AMOTL1',
#   'AMER1',
#   'NOTCH4'],
#  'RPAP3': ['ZNHIT3',
#   'PPP1CC',
#   'ASB7',
#   'CCDC103',
#   'POLR2A',
#   'SMG1',
#   'DPCD',
#   'HSP90AA1',
#   'PIH1D2',
#   'PIH1D3',
#   'URI1',
#   'HSPA4',
#   'POLR2J',
#   'MED17',
#   'RPAP1',
#   'CHTF18',
#   'HSP90AB1',
#   'MPHOSPH10',
#   'NOP58',
#   'BLOC1S6',
#   'ESF1',
#   'POLR1A',
#   'NHP2',
#   'FAM187A',
#   'IKBKG',
#   'SUGT1',
#   'PPP1CA',
#   'ODF3',
#   'RUVBL2',
#   'FAM19A1',
#   'PFDN2',
#   'DNAH2',
#   'RUVBL1',
#   'PDRG1',
#   'NUFIP1',
#   'POLR2E',
#   'RPAP2',
#   'TTI2',
#   'SHQ1',
#   'UXT',
#   'PIH1D1',
#   'INTS3',
#   'ZNHIT2',
#   'GPN1',
#   'POLR2B',
#   'ZNHIT6',
#   'PFDN6',
#   'PTGES3',
#   'WDR92',
#   'POLR3A',
#   'TELO2',
#   'DNAAF2',
#   'TTI1'],
#  'SKAP2': ['FYB',
#   'TATDN3',
#   'FYN',
#   'WAS',
#   'GM2A',
#   'LYN',
#   'ITGB1',
#   'CSMD2',
#   'SIRPA',
#   'FDFT1',
#   'PTPN22',
#   'PTK2B',
#   'ITGA5',
#   'PPP6R1',
#   'ITGA4',
#   'CD47',
#   'SRC'],
#  'PRSS21': ['AGMAT'],
#  'HOXA11': ['SIX2', 'HOXA13', 'GMNN', 'FOXO1', 'MEIS1'],
#  'CX3CL1': ['IL5',
#   'TNF',
#   'BDNF',
#   'CSF2',
#   'VCAM1',
#   'CXCL10',
#   'CCR8',
#   'CCR4',
#   'CXCL5',
#   'IL13',
#   'CCL11',
#   'CXCL1',
#   'CXCL16',
#   'CCL17',
#   'CCL7',
#   'ITGAM',
#   'ITGB3',
#   'CXCR3',
#   'XCL1',
#   'ADAM17',
#   'FN1',
#   'CCR7',
#   'CCR9',
#   'CXCR5',
#   'CCL22',
#   'CCL3',
#   'CXCR6',
#   'CCL20',
#   'IL10',
#   'CXCL2',
#   'VEGFA',
#   'CD200',
#   'CD200R1',
#   'CSF3',
#   'CCL21',
#   'ADAM10',
#   'IL15',
#   'CCL4L1',
#   'IFNG',
#   'CCL5',
#   'CXCR4',
#   'IL6',
#   'CXCL8',
#   'IL1B',
#   'CXCR2',
#   'ICAM1',
#   'CXCR1',
#   'CXCL12',
#   'GPR29',
#   'CCR5',
#   'LTA',
#   'AIF1',
#   'CCR3',
#   'IL17A',
#   'CXCL11',
#   'CCR2',
#   'CXCL9',
#   'XCR1',
#   'CX3CR1',
#   'CCR1',
#   'CCR10',
#   'IL1A',
#   'CCL4',
#   'CCL2',
#   'IL4'],
#  'TRAPPC6A': ['SEC24A',
#   'GOSR2',
#   'SEC22A',
#   'TRAPPC3',
#   'SEC22C',
#   'TRAPPC2P1',
#   'TRAPPC11',
#   'SEC22B',
#   'TRAPPC10',
#   'TRAPPC5',
#   'CD59',
#   'SEC23A',
#   'CNIH3',
#   'SERPINA1',
#   'YKT6',
#   'TIAF1',
#   'ENSG00000280433',
#   'GOLGA2',
#   'LMAN2L',
#   'TRAPPC2',
#   'NKPD1',
#   'RAB1A',
#   'TRAPPC4',
#   'SEC31A',
#   'GDI1',
#   'CNIH1',
#   'CTSZ',
#   'CHML',
#   'SEC24B',
#   'TRAPPC6B',
#   'CHM',
#   'SEC13',
#   'TRAPPC3L',
#   'F5',
#   'GORASP1',
#   'TRAPPC1',
#   'TRAPPC8',
#   'SEC24D',
#   'FOLR1',
#   'WWOX',
#   'LMAN2',
#   'SH3GLB2',
#   'LMAN1',
#   'CTSC',
#   'USO1',
#   'TRAPPC12',
#   'TMED2',
#   'LMAN1L',
#   'TMED10',
#   'GDI2',
#   'MCFD2',
#   'TRAPPC9',
#   'SEC23IP',
#   'CNIH2',
#   'TRAPPC2L',
#   'AREG',
#   'SEC24C',
#   'RAB1B',
#   'STX5',
#   'COL7A1',
#   'F8',
#   'TRAPPC13',
#   'GRIA1',
#   'TGFA'],
#  'WDR54': ['CFAP44',
#   'DUS3L',
#   'CCDC140',
#   'ZBTB11',
#   'SPCS2',
#   'ZNHIT3',
#   'ZZEF1',
#   'WDR53',
#   'OSCP1',
#   'CD99L2'],
#  'SPATA20': ['NDUFV2',
#   'SPATA17',
#   'SPATA16',
#   'SPATA25',
#   'LGMN',
#   'SPATA3',
#   'RABGGTB',
#   'CSNK1D',
#   'CSNK1E',
#   'SAT2',
#   'SPATA18',
#   'C1orf111',
#   'SPATA9',
#   'SPATA6',
#   'SPATA4'],
#  'RHBDD2': ['RHBDF1',
#   'DERL2',
#   'MXD1',
#   'FRMD8',
#   'PARL',
#   'UBAC2',
#   'RHBDL1',
#   'RHBDD1',
#   'RHBDL2',
#   'DERL3',
#   'GRTP1'],
#  'TSR3': ['RRP8',
#   'B3GALTL',
#   'TSR1',
#   'NOB1',
#   'WBSCR22',
#   'EMG1',
#   'DTWD1',
#   'CFP',
#   'TRMT10A',
#   'LTV1',
#   'TSR2',
#   'TRMT12',
#   'POFUT2',
#   'TBL2',
#   'ADAMTSL2',
#   'PDCD2',
#   'OPLAH'],
#  'OSBPL7': ['TYW1B', 'PLEK', 'VAPA', 'GAK'],
#  'YBX2': ['BTF3L4',
#   'DAZL',
#   'RBM44',
#   'CTNS',
#   'BTG3',
#   'SPEM1',
#   'SOHLH1',
#   'DDX6',
#   'HABP4',
#   'NACA',
#   'LSM14A',
#   'FETUB',
#   'LHX8',
#   'ZP3',
#   'PI4K2B',
#   'NOBOX',
#   'TSN',
#   'KHDC3L',
#   'GNG13',
#   'NACA2',
#   'NEURL4',
#   'NIPAL4',
#   'FIGLA',
#   'NANOS2',
#   'ZP2'],
#  'ITGA3': ['ITGAV',
#   'PARVB',
#   'ITGA11',
#   'SPP1',
#   'ACTB',
#   'ITGB7',
#   'ITGAL',
#   'COL18A1',
#   'AGRN',
#   'CRK',
#   'CALR',
#   'COMP',
#   'LAMB1',
#   'ITGA10',
#   'COL4A1',
#   'INCENP',
#   'ITGA7',
#   'PTK2',
#   'PLAU',
#   'CHAD',
#   'ITGA8',
#   'ITGA1',
#   'COL4A4',
#   'PLAUR',
#   'THBS4',
#   'ITGB1',
#   'TNXB',
#   'LGALS8',
#   'BSG',
#   'JAM3',
#   'EGFR',
#   'FLNB',
#   'COL9A3',
#   'LAMB2',
#   'LAMA4',
#   'CHRNA3',
#   'COL2A1',
#   'ITGB8',
#   'ITGA5',
#   'ITGAD',
#   'LAMA5',
#   'ITGAE',
#   'TLN1',
#   'PARVA',
#   'IBSP',
#   'FLNA',
#   'VASP',
#   'CD80',
#   'AEBP2',
#   'RELN',
#   'FLNC',
#   'LAMC2',
#   'ITGA4',
#   'ENSG00000250349',
#   'CD151',
#   'EPHA2',
#   'ACTN4',
#   'COL9A2',
#   'LAMB4',
#   'LAMA2',
#   'COL4A5',
#   'DAB1',
#   'ITGAX',
#   'CD28',
#   'COL6A2',
#   'BCAR1',
#   'TNN',
#   'CSPG4',
#   'THBS3',
#   'COL9A1',
#   'MET',
#   'ARF6',
#   'ITGA2',
#   'THBS1',
#   'ITGB2',
#   'TLN2',
#   'CRKL',
#   'TNC',
#   'LAMC3',
#   'TSPAN8',
#   'COL4A6',
#   'LAMA1',
#   'PRKCA',
#   'VTN',
#   'FN1',
#   'TNR',
#   'COL6A6',
#   'ITGAM',
#   'ITGB3',
#   'VEGFA',
#   'CD164',
#   'ITGB5',
#   'ACTG1',
#   'PARVG',
#   'COL1A1',
#   'ITGB4',
#   'MAGED1',
#   'ACTN1',
#   'JAM2',
#   'CTLA4',
#   'HGF',
#   'COL6A3',
#   'COL6A5',
#   'ITGA9',
#   'LAMC1',
#   'TFRC',
#   'VWF',
#   'CD9',
#   'THBS2',
#   'RAB21',
#   'NID1',
#   'ITGB6',
#   'VLDLR',
#   'TGFBI',
#   'LAMB3',
#   'COL4A2',
#   'COL6A1',
#   'COL1A2',
#   'COL4A3',
#   'RABIF',
#   'LAMA3',
#   'ITGBL1',
#   'ITGA6',
#   'SRC',
#   'LRP8'],
#  'KRT33A': ['KRT27'],
#  'TFAP2D': ['SPATA4',
#   'KCTD15',
#   'CITED4',
#   'YEATS4',
#   'CITED2',
#   'CITED1',
#   'ABT1',
#   'ZCCHC3',
#   'EP300',
#   'TRIM40',
#   'AGPAT5',
#   'CREBBP',
#   'KCTD1'],
#  'CRY1': ['PPP1CC',
#   'CLOCK',
#   'RORA',
#   'TEF',
#   'FTO',
#   'NPAS2',
#   'OPN4',
#   'NR1D2',
#   'ARNT',
#   'BHLHE40',
#   'PPP1CB',
#   'AANAT',
#   'HLF',
#   'CRY2',
#   'CSNK1D',
#   'CUL1',
#   'UBB',
#   'NR1D1',
#   'PRKAA1',
#   'PER1',
#   'SIN3B',
#   'PRH1',
#   'SKP1',
#   'TEKT4',
#   'TIMELESS',
#   'BTRC',
#   'PRKAG2',
#   'SIRT1',
#   'PPP1CA',
#   'PRKAG3',
#   'UBA52',
#   'RORB',
#   'PRKAA2',
#   'DET1',
#   'PRH2',
#   'CCRN4L',
#   'FBXL3',
#   'PRKAG1',
#   'ARNTL2',
#   'CSNK1E',
#   'PER2',
#   'PER3',
#   'PRKAB2',
#   'PRKAB1',
#   'NR3C1',
#   'NFIL3',
#   'ARNTL',
#   'USP2',
#   'RPS27A',
#   'DBP',
#   'QPRT',
#   'CSNK2B',
#   'UBC',
#   'RORC',
#   'BHLHE41'],
#  'PGLYRP1': ['DLG5',
#   'HSPA4',
#   'TECR',
#   'CAMP',
#   'TREM1',
#   'TNFRSF1A',
#   'S100A4',
#   'DEFA4',
#   'IKBKB',
#   'BPI'],
#  'STARD3NL': ['TOX4',
#   'AMPH',
#   'MOSPD3',
#   'ZBTB40',
#   'DNTT',
#   'NPC2',
#   'SALL2',
#   'DCDC1',
#   'COMMD3',
#   'ACTR8',
#   'EPDR1',
#   'RCBTB1',
#   'STAR',
#   'STARD3',
#   'HECW1',
#   'MOSPD2',
#   'VAPA',
#   'OGFRL1',
#   'NPC1',
#   'VAPB'],
#  'CAMK1G': ['CREB3L4',
#   'ATF6B',
#   'NOS3',
#   'CALM2',
#   'CREB1',
#   'CALML4',
#   'CREB3L3',
#   'CALML5',
#   'CALML3',
#   'ATF2',
#   'CREB3L1',
#   'CREB3L2',
#   'ATF4',
#   'ATF1',
#   'CREB5',
#   'JAM2',
#   'F11R',
#   'NLE1',
#   'CALML6',
#   'JAM3',
#   'CREB3'],
#  'CD74': ['TNF',
#   'AP2A2',
#   'ENSG00000248993',
#   'CANX',
#   'AP2B1',
#   'C1QB',
#   'AP1S3',
#   'SEC13',
#   'CTSC',
#   'CD1D',
#   'AP1S2',
#   'CD4',
#   'AP1S1',
#   'HLA-DPA1',
#   'SAR1B',
#   'HLA-DRA',
#   'HLA-B',
#   'ITGB2',
#   'CIITA',
#   'CD53',
#   'SH3GL2',
#   'CTSS',
#   'HLA-A',
#   'COPG2',
#   'C1QA',
#   'CLTA',
#   'HLA-DRB5',
#   'CTSV',
#   'EML4',
#   'HLA-DQB2',
#   'HLA-DQB1',
#   'LY86',
#   'CXCR2',
#   'SEC24D',
#   'AP1B1',
#   'ARF1',
#   'COPG1',
#   'HLA-DRB1',
#   'ZEB1',
#   'ROS1',
#   'B2M',
#   'HERPUD1',
#   'DNM2',
#   'HLA-DQA1',
#   'SEC23A',
#   'CD44',
#   'HLA-DMA',
#   'CSF1R',
#   'LCP1',
#   'HLA-DOB',
#   'MIF',
#   'IRF8',
#   'CTSO',
#   'AP2M1',
#   'DDT',
#   'CD86',
#   'DNM1',
#   'AP1M2',
#   'AP1G1',
#   'AP2A1',
#   'SEC24A',
#   'CTSD',
#   'AP2S1',
#   'LAPTM5',
#   'CTSK',
#   'COPS5',
#   'ITGAM',
#   'CTSB',
#   'LGMN',
#   'SEC24C',
#   'CTSE',
#   'LRIG3',
#   'SLC34A2',
#   'CTSA',
#   'TP53',
#   'APP',
#   'DNM3',
#   'SEC24B',
#   'CTSL',
#   'CXCR4',
#   'HLA-DPB1',
#   'HLA-DQA2',
#   'CTSF',
#   'HLA-DOA',
#   'PTPRC',
#   'CXCR1',
#   'SEC31A',
#   'MAPK3',
#   'HLA-DMB',
#   'AP1M1',
#   'TYROBP',
#   'ALK',
#   'CTSH',
#   'CLTC',
#   'FCGRT'],
#  'FAM76A': ['ODF3L2'],
#  'CPA1': ['CTRL',
#   'CELA2B',
#   'LXN',
#   'CELA1',
#   'PNLIPRP1',
#   'PRSS3P2',
#   'CEL',
#   'PNLIP',
#   'SLC9B2',
#   'CELA2A',
#   'CTRB1',
#   'NEUROG3',
#   'CPA3',
#   'CELA3A',
#   'CPB1',
#   'PRSS1',
#   'CELA3B',
#   'RBPJL',
#   'CPA2',
#   'CTRC',
#   'SYCN',
#   'ING1',
#   'AMY2A',
#   'CLPS',
#   'SPINK1',
#   'PRSS58',
#   'PTF1A',
#   'CTRB2'],
#  'SYPL1': ['ZNF550', 'SCAMP1', 'VAMP2', 'COG5'],
#  'RANBP9': ['MET',
#   'SFRP2',
#   'KRAS',
#   'NRAS',
#   'GID8',
#   'USP11',
#   'FBXO45',
#   'MAEA',
#   'LTB4R2',
#   'MKLN1',
#   'RANBP10',
#   'DYRK1B',
#   'TGFBR1',
#   'HIPK2',
#   'FMR1',
#   'SOS1',
#   'GID4',
#   'HGF',
#   'CEND1',
#   'MPHOSPH8',
#   'TAF4',
#   'AXL',
#   'TRIM36',
#   'AHI1',
#   'RMND5B',
#   'CALB1',
#   'GRB2',
#   'PLXNA1',
#   'DDX4',
#   'CDK11B',
#   'SPAG8',
#   'DCTN1',
#   'TRAF6',
#   'KCTD6',
#   'HMBS',
#   'TP53',
#   'RAF1',
#   'HDAC6',
#   'ARMC8',
#   'RMND5A',
#   'ADAP2',
#   'YPEL5',
#   'WDR26',
#   'HRAS',
#   'ENTPD1',
#   'L1CAM',
#   'CLEC7A',
#   'RAN'],
#  'CD4': ['HLA-C',
#   'TIA1',
#   'TLR8',
#   'RGS1',
#   'ITGAM',
#   'ACKR2',
#   'ERVW-1',
#   'CR1',
#   'SPI1',
#   'CXCR5',
#   'CCR7',
#   'AP2S1',
#   'NCAM1',
#   'TBX21',
#   'SERPINB8',
#   'ENSG00000255819',
#   'CXCL2',
#   'CCL20',
#   'CXCR6',
#   'CLTB',
#   'IKZF1',
#   'SELE',
#   'TRAT1',
#   'GNAI1',
#   'ICAM3',
#   'SHC1',
#   'THBD',
#   'IL23A',
#   'AP2A1',
#   'MAPK14',
#   'S1PR1',
#   'SYK',
#   'MBP',
#   'IRF4',
#   'VEGFA',
#   'ATP9A',
#   'CXCL1',
#   'IL33',
#   'CCL11',
#   'CD1B',
#   'PRKCQ',
#   'CXCL5',
#   'CD5',
#   'CD28',
#   'ITGAX',
#   'SAMHD1',
#   'HCK',
#   'COPA',
#   'CSF1',
#   'PRDM1',
#   'MATK',
#   'CCL27',
#   'PTPN11',
#   'BTRC',
#   'CCL17',
#   'IFNGR1',
#   'CCL7',
#   'SDC1',
#   'GNAO1',
#   'TLR2',
#   'ENSG00000277117',
#   'CD86',
#   'GNAI3',
#   'VIP',
#   'CD247',
#   'FAS',
#   'VCAM1',
#   'AP2M1',
#   'CSF2',
#   'CD34',
#   'TNFSF8',
#   'GPT',
#   'BCL6',
#   'CD58',
#   'CCR8',
#   'SERPINB7',
#   'SERPINB3',
#   'TLR3',
#   'DBNL',
#   'CD52',
#   'IRF8',
#   'CD3G',
#   'RAG1',
#   'TNFSF11',
#   'STAT5B',
#   'TGFB1',
#   'KLRB1',
#   'SKP1',
#   'HLA-DOB',
#   'FOXP3',
#   'PTPN6',
#   'PECAM1',
#   'PTK2B',
#   'CD46',
#   'CD38',
#   'TIMD4',
#   'CD19',
#   'CD207',
#   'HIST2H2BE',
#   'CSF1R',
#   'SOCS1',
#   'CD6',
#   'TIGIT',
#   'CXCL3',
#   'ENSG00000272980',
#   'IFNAR1',
#   'IL23R',
#   'SLCO2A1',
#   'CD209',
#   'IL7',
#   'CD44',
#   'GNAI2',
#   'HLA-DMA',
#   'CXCL9',
#   'CCR2',
#   'CXCL11',
#   'TRAF6',
#   'FCGRT',
#   'GNAZ',
#   'PTK2',
#   'KLRD1',
#   'LILRB2',
#   'CCR1',
#   'MAF',
#   'CD33',
#   'IL4',
#   'SIRPA',
#   'IL17F',
#   'CCL2',
#   'ALB',
#   'CD68',
#   'IDO1',
#   'ENPEP',
#   'IL16',
#   'CUL1',
#   'MME',
#   'TYROBP',
#   'IL21',
#   'PTGDR2',
#   'CRP',
#   'SELP',
#   'SELL',
#   'GRAP2',
#   'SLA2',
#   'MMP9',
#   'THY1',
#   'HLA-DMB',
#   'CD1C',
#   'IFNAR2',
#   'HLA-DOA',
#   'GPR29',
#   'ZBTB7B',
#   'PTPRC',
#   'ICAM1',
#   'GNB1',
#   'FYN',
#   'LTA',
#   'IL7R',
#   'UCHL1',
#   'RUNX3',
#   'DNTT',
#   'JAK3',
#   'AIF1',
#   'ENSG00000173366',
#   'PTCRA',
#   'GZMA',
#   'SERPINB2',
#   'ITGAL',
#   'JUN',
#   'GAPDH',
#   'B3GAT1',
#   'CD22',
#   'CD1A',
#   'CD83',
#   'TLR10',
#   'ZAP70',
#   'STAT4',
#   'ITGA4',
#   'CD7',
#   'IL4R',
#   'HLA-DPB1',
#   'ERVMER34-1',
#   'IL2RB',
#   'HLA-DQA2',
#   'MOG',
#   'GZMB',
#   'STAT1',
#   'PIP',
#   'SH3BP2',
#   'CXCR4',
#   'CD163',
#   'MTOR',
#   'CTNNB1',
#   'IL6R',
#   'CXCL8',
#   'MICA',
#   'PCSK5',
#   'PTPN22',
#   'JAK2',
#   'TP53',
#   'TNFRSF4',
#   'LAMP1',
#   'TSLP',
#   'LILRB1',
#   'FUT4',
#   'CCL21',
#   'FLNA',
#   'GOLPH3',
#   'LY75',
#   'LAG3',
#   'P4HB',
#   'IL2RA',
#   'IFNA1',
#   'ITGAE',
#   'IL15',
#   'IRF1',
#   'CXCR3',
#   'IFNB1',
#   'PDCD1',
#   'EOMES',
#   'AIRE',
#   'C3',
#   'CCR9',
#   'RAG2',
#   'FN1',
#   'HAND2',
#   'PAG1',
#   'SERPINB5',
#   'XCL1',
#   'CD1E',
#   'VAV1',
#   'CDR2',
#   'FLT3',
#   'IL10',
#   'CCL3',
#   'CCL22',
#   'FCGR3B',
#   'HLA-A',
#   'LITAF',
#   'FCGR2A',
#   'CD79A',
#   'RORC',
#   'TNFRSF9',
#   'IL21R',
#   'KIT',
#   'PDCD1LG2',
#   'NFATC1',
#   'BST2',
#   'CD53',
#   'NLRP3',
#   'CASP3',
#   'IL13',
#   'TNFSF13B',
#   'MRC1',
#   'CDKN2A',
#   'CIITA',
#   'NOD2',
#   'LTBR',
#   'SOCS3',
#   'FASLG',
#   'STAT5A',
#   'CD3E',
#   'HLA-B',
#   'ITGB2',
#   'IL2',
#   'TLR6',
#   'ITGA2',
#   'HLA-DPA1',
#   'THBS1',
#   'DUSP1',
#   'SCD5',
#   'HLA-DRA',
#   'CD81',
#   'MADCAM1',
#   'CLEC4C',
#   'DEFA3',
#   'AKT1',
#   'IL12RB1',
#   'MKI67',
#   'CD48',
#   'ARG2',
#   'ERBB2',
#   'CR2',
#   'CD1D',
#   'TLR9',
#   'ERVV-1',
#   'CXCL10',
#   'STAT6',
#   'LGALS3',
#   'FBXW11',
#   'TNFRSF18',
#   'SRC',
#   'CD2',
#   'RBX1',
#   'ICOS',
#   'ANPEP',
#   'JAK1',
#   'PPBP',
#   'CD82',
#   'AP2B1',
#   'HPRT1',
#   'CCL19',
#   'CTLA4',
#   'CD274',
#   'HLA-E',
#   'FLT3LG',
#   'KLRG1',
#   'CBL',
#   'GNLY',
#   'FCGR1A',
#   'AHR',
#   'IRF7',
#   'ITIH4',
#   'DDX53',
#   'CD9',
#   'MAP4K1',
#   'SDCBP',
#   'IL5',
#   'CD70',
#   'TFRC',
#   'AP2A2',
#   'SPN',
#   'ITK',
#   'NT5E',
#   'TNF',
#   'LAT',
#   'TRIM5',
#   'CX3CR1',
#   'XCR1',
#   'PMEL',
#   'TLR7',
#   'NRP1',
#   'IL17A',
#   'ARG1',
#   'IGHV4-38-2',
#   'HLA-DQA1',
#   'IL2RG',
#   'PRF1',
#   'CD244',
#   'CSK',
#   'DPP4',
#   'CCL4',
#   'IL1A',
#   'CEACAM1',
#   'DDX58',
#   'PTPRJ',
#   'IL9',
#   'TNXB',
#   'MLLT4',
#   'TNFRSF10A',
#   'CD276',
#   'ITGB1',
#   'IL3',
#   'GNG2',
#   'SLAMF6',
#   'INS',
#   'ACTB',
#   'CD8B',
#   'CD40',
#   'B2M',
#   'FCGR2B',
#   'TNFRSF14',
#   'TLR5',
#   'CD3D',
#   'KLRK1',
#   'CXCL12',
#   'CD160',
#   'FYB',
#   'IL22',
#   'CD24',
#   'CTAG1B',
#   'IL17RA',
#   'CCRL2',
#   'VCP',
#   'LCK',
#   'CD69',
#   'CCR5',
#   'CD8A',
#   'HAVCR2',
#   'DLL1',
#   'SLAMF1',
#   'TNFRSF8',
#   'TNFSF4',
#   'CCR3',
#   'CASP1',
#   'CD27',
#   'CD74',
#   'HLA-DRB1',
#   'TNFSF10',
#   'SIGLEC1',
#   'IL10RA',
#   'PLCG1',
#   'NAALADL1',
#   'BATF',
#   'TNFRSF25',
#   'TLR4',
#   'EMR1',
#   'NOS2',
#   'CD14',
#   'APOA1',
#   'CLEC7A',
#   'ENSG00000250349',
#   'PLVAP',
#   'BCL2L1',
#   'AOC3',
#   'CCL4L1',
#   'LGALS9',
#   'ANXA5',
#   'TNFSF18',
#   'TNFSF9',
#   'CXCL13',
#   'ARF1',
#   'CCL5',
#   'PCSK7',
#   'IFNG',
#   'IL6',
#   'BTLA',
#   'IL3RA',
#   'MPO',
#   'TNFRSF1A',
#   'NOTCH1',
#   'ENTPD1',
#   'CD40LG',
#   'CTAG1A',
#   'HLA-G',
#   'APOBEC3G',
#   'FCGR3A',
#   'TNFRSF1B',
#   'B7RP1',
#   'CXCR2',
#   'IL1B',
#   'NCR1',
#   'GATA3',
#   'STAT3',
#   'HLA-DQB1',
#   'CSF3',
#   'HLA-DQB2',
#   'LCP2',
#   'DDIT3',
#   'SELPLG',
#   'CFTR',
#   'KLRC1',
#   'PSTPIP1',
#   'MYD88',
#   'TOR1A',
#   'RAB4A',
#   'LNPEP',
#   'TLR1',
#   'CD80',
#   'NELFCD',
#   'KCNN3',
#   'CLTA',
#   'PIK3CA',
#   'IL18',
#   'IL1R1',
#   'MYC',
#   'HLA-DRB5'],
#  'TSPAN9': ['THAP3',
#   'TEAD2',
#   'KIF24',
#   'PPFIBP1',
#   'TSPAN32',
#   'YAP1',
#   'CDX2',
#   'DNAJC11',
#   'C12orf5',
#   'RFESD',
#   'TEAD1',
#   'DENND2D',
#   'RPS27',
#   'TEAD3'],
#  'QPCTL': ['ZMIZ1',
#   'GIPR',
#   'FAIM2',
#   'TMEM18',
#   'GNPDA2',
#   'ADHFE1',
#   'POC5',
#   'ARMC6',
#   'SH2B1',
#   'MTCH2',
#   'TNNI3K',
#   'SEC16B',
#   'NUDT3',
#   'SYTL3',
#   'MTIF3',
#   'WDR6',
#   'ZNF608',
#   'TMEM160',
#   'DNAJC27',
#   'ZC3H4'],
#  'PPP5C': ['TATDN1',
#   'RNF168',
#   'HIST1H2BD',
#   'HIST1H2BM',
#   'WHSC1',
#   'RAD50',
#   'UBE2V2',
#   'CCT5',
#   'UBE2N',
#   'HIST1H2BL',
#   'HSPA8',
#   'CCT4',
#   'ESR2',
#   'STUB1',
#   'CCT8',
#   'TSC1',
#   'ITGB1BP2',
#   'NR3C1',
#   'PSMG2',
#   'BAG2',
#   'H2AFX',
#   'FKBP5',
#   'CCT6A',
#   'CHORDC1',
#   'STIP1',
#   'TRAP1',
#   'TCP1',
#   'AHSA1',
#   'PPP2R4',
#   'HIST1H2BA',
#   'PIAS4',
#   'YWHAB',
#   'PTGES3',
#   'PSMG1',
#   'MAPT',
#   'HIST1H2BB',
#   'CCT6B',
#   'CCT7',
#   'KRAS',
#   'ESR1',
#   'H2BFS',
#   'KAT5',
#   'RAF1',
#   'HIST1H2BH',
#   'MDC1',
#   'HSF1',
#   'PPID',
#   'HRAS',
#   'BAG3',
#   'ARAF',
#   'RNF8',
#   'HSP90AA1',
#   'MAPK3',
#   'HIST1H2BK',
#   'BRAF',
#   'PPM1L',
#   'CDC37',
#   'HIST1H2BO',
#   'FKBP4',
#   'PSPC1',
#   'HIST2H2BE',
#   'HERC2',
#   'CCT2',
#   'PPP2R1A',
#   'MAPK1',
#   'HIST1H2BN',
#   'HSP90AB1',
#   'SUMO1',
#   'HIST1H2BJ',
#   'CCT3',
#   'HIST3H3',
#   'HSPB8',
#   'NRAS',
#   'NBN',
#   'KSR1',
#   'TP53BP1',
#   'MAP3K5',
#   'MRE11A',
#   'ATM'],
#  'UBR7': ['HIST1H3J',
#   'HIST1H3A',
#   'UBR3',
#   'THOC1',
#   'THOC5',
#   'UBR1',
#   'UBR4',
#   'UBR2',
#   'DNAJC9',
#   'FBXO11',
#   'NASP',
#   'UBR5'],
#  'MAP4K5': ['TNF',
#   'MAP3K1',
#   'MAP3K5',
#   'MAP3K7',
#   'TRAF2',
#   'ATL1',
#   'TNFRSF1A',
#   'GRB2',
#   'CRK',
#   'MAP3K11',
#   'TRADD'],
#  'INMT': ['FMO1',
#   'AOC1',
#   'MAOA',
#   'IDO2',
#   'IDO1',
#   'DDC',
#   'HTR7',
#   'AANAT',
#   'FAM188B',
#   'TFAP2A',
#   'MAOB'],
#  'ERCC1': ['TYMS',
#   'XAB2',
#   'PMS2',
#   'FANCD2',
#   'RRM1',
#   'FAN1',
#   'HUS1',
#   'AQR',
#   'USP1',
#   'POLD3',
#   'USP7',
#   'POLR2B',
#   'RBX1',
#   'DDB1',
#   'XRCC2',
#   'XRCC6BP1',
#   'TOPBP1',
#   'PRKDC',
#   'DPYD',
#   'DDB2',
#   'ATR',
#   'PRPF19',
#   'RAD54B',
#   'POLR2I',
#   'RPA1',
#   'BLM',
#   'FANCI',
#   'UBB',
#   'BARD1',
#   'NHEJ1',
#   'SLX1B',
#   'UBL7',
#   'LIG4',
#   'ERCC3',
#   'GEN1',
#   'GSTP1',
#   'CUL4B',
#   'DCLRE1A',
#   'BRIP1',
#   'CD3EAP',
#   'MUS81',
#   'UBC',
#   'POLE4',
#   'TBP',
#   'FANCL',
#   'RCOR1',
#   'LIG1',
#   'NBN',
#   'RAD52',
#   'POLD1',
#   'MSH2',
#   'TP53BP1',
#   'SLX4',
#   'PCNA',
#   'POLE3',
#   'ERCC6',
#   'SWSAP1',
#   'KAT5',
#   'ENSG00000258947',
#   'UBA52',
#   'MSH3',
#   'RAD23B',
#   'PNKP',
#   'ATM',
#   'REV3L',
#   'POLE2',
#   'MRE11A',
#   'CDK7',
#   'RMI2',
#   'APITD1',
#   'ENSG00000258838',
#   'ERCC5',
#   'RPS27A',
#   'FANCF',
#   'XRCC5',
#   'BRCA2',
#   'STRA13',
#   'PARP2',
#   'MSH4',
#   'SLC25A15',
#   'RFC5',
#   'RBBP8',
#   'GTF2H2',
#   'MLH1',
#   'FANCG',
#   'POLR2K',
#   'C1orf86',
#   'RAD1',
#   'BIVM-ERCC5',
#   'RAD50',
#   'ZNF830',
#   'DCLRE1B',
#   'POLE',
#   'RPA3',
#   'POLR2A',
#   'MGMT',
#   'POLK',
#   'ZSWIM7',
#   'USP45',
#   'FANCB',
#   'C19orf40',
#   'XPA',
#   'SLX1A',
#   'RHNO1',
#   'APTX',
#   'PPIE',
#   'POLD2',
#   'RAD54L',
#   'POLR2C',
#   'C9orf142',
#   'MSH6',
#   'SLX4IP',
#   'HMGN1',
#   'POLH',
#   'GTF2H5',
#   'APEX2',
#   'MSH5',
#   'RAD51',
#   'RAD23A',
#   'CHD1L',
#   'RAD51C',
#   'ATRIP',
#   'ERCC2',
#   'TP53',
#   'EME1',
#   'EGFR',
#   'EXO1',
#   'RMI1',
#   'RAD9A',
#   'XRCC6',
#   'TCEA1',
#   'RFC3',
#   'FANCC',
#   'UBE2T',
#   'APEX1',
#   'POLR2G',
#   'CCNH',
#   'MLH3',
#   'TOP3A',
#   'TOP1',
#   'RAD18',
#   'MDC1',
#   'XRCC3',
#   'POLR2F',
#   'RFC1',
#   'BRCA1',
#   'REV1',
#   'POLR2E',
#   'POLR2L',
#   'PMS1',
#   'XRCC1',
#   'OGG1',
#   'CHEK2',
#   'POLR2D',
#   'POLR2J',
#   'C17orf70',
#   'FANCE',
#   'TDP1',
#   'RAD17',
#   'EME2',
#   'MMS19',
#   'UVSSA',
#   'ERCC8',
#   'EP300',
#   'LIG3',
#   'TUBB3',
#   'FANCM',
#   'XRCC4',
#   'ERCC4',
#   'FEN1',
#   'WDR48',
#   'PARP1',
#   'POLN',
#   'KDM1A',
#   'GTF2H1',
#   'POLR2H',
#   'CUL4A',
#   'RAD9B',
#   'RFC4',
#   'WRN',
#   'NTHL1',
#   'POLD4',
#   'GTF2H3',
#   'GTF2H4',
#   'CHEK1',
#   'PHF21A',
#   'RFC2',
#   'FANCA',
#   'MNAT1',
#   'RPA2',
#   'DCLRE1C',
#   'XPC',
#   'CETN2',
#   'DNA2'],
#  'GPRC5A': ['SLC25A3',
#   'TSPEAR',
#   'SMYD5',
#   'EIF4A1',
#   'KRTCAP3',
#   'GRM2',
#   'RARS',
#   'GTF2F2',
#   'FXYD3',
#   'NOLC1'],
#  'HEBP1': ['PTDSS2',
#   'CCL23',
#   'FPR1',
#   'FPR3',
#   'FPR2',
#   'UBE2L3',
#   'ANXA1',
#   'COTL1',
#   'SAA1',
#   'APP'],
#  'COX15': ['FASTKD2',
#   'COX4I2',
#   'COX6A1',
#   'COQ5',
#   'UQCRHL',
#   'TOMM22',
#   'MT-CO2',
#   'NDUFS8',
#   'COA3',
#   'UQCR10',
#   'COX20',
#   'COX8A',
#   'DNAJC1',
#   'ABCB7',
#   'UQCRQ',
#   'LRPPRC',
#   'COA6',
#   'MT-CO1',
#   'MT-CYB',
#   'OXA1L',
#   'MRPL15',
#   'UQCRC1',
#   'COX7B',
#   'CYC1',
#   'FDXR',
#   'TACO1',
#   'COX7B2',
#   'COQ6',
#   'ATP5H',
#   'COX11',
#   'NDUFA4L2',
#   'ISCU',
#   'UQCRFS1',
#   'MSS51',
#   'SLC25A3',
#   'PET117',
#   'COX18',
#   'CDKL3',
#   'COX16',
#   'BCS1L',
#   'COX17',
#   'SCO1',
#   'FDX1L',
#   'ATP5S',
#   'COX4I1',
#   'COX19',
#   'COX10',
#   'NDUFA4',
#   'PPOX',
#   'SDHA',
#   'CYCS',
#   'MT-ATP6',
#   'ATPAF2',
#   'SURF1',
#   'NDUFS7',
#   'COX7C',
#   'COX6A2',
#   'FXN',
#   'COX7A2',
#   'SDHC',
#   'NDUFS6',
#   'ETHE1',
#   'COX14',
#   'ATP5G3',
#   'HCCS',
#   'COX8C',
#   'LAMA4',
#   'UQCRH',
#   'FBXW4',
#   'MT-CO3',
#   'SCO2',
#   'NDUFS4',
#   'COX6B1',
#   'UQCRC2',
#   'COQ9',
#   'UQCRB',
#   'COA5',
#   'NDUFA12',
#   'ATPAF1',
#   'COX5A',
#   'SDHB',
#   'ACO2'],
#  'MS4A12': ['TMEM176A', 'ZG16', 'CLCA4', 'GUCA2A', 'AQP8'],
#  'RGPD5': ['RAN', 'XPO1', 'GRIP1', 'RANGAP1', 'MLLT10', 'NXF1', 'TNPO1'],
#  'XYLT2': ['CSPG4',
#   'BGN',
#   'BCAN',
#   'SDC1',
#   'B3GAT3',
#   'B3GALT6',
#   'SDC3',
#   'FAM20A',
#   'SDC2',
#   'ABCC6',
#   'SDC4',
#   'GPC2',
#   'GPC1',
#   'GPC5',
#   'UXS1',
#   'GPC6',
#   'SLC6A20',
#   'GPC3',
#   'CHST14',
#   'AGRN',
#   'GRB2',
#   'XYLT1',
#   'GPC4',
#   'HSPG2',
#   'VCAN',
#   'CSPG5',
#   'EXTL3',
#   'NCAN',
#   'EXTL2',
#   'B4GALT3',
#   'B4GALT7',
#   'DCN',
#   'FAM20B',
#   'CHPF'],
#  'SCTR': ['VIP',
#   'RAMP3',
#   'ADCYAP1',
#   'AGTR1',
#   'GNGT1',
#   'GIP',
#   'GNG4',
#   'GNG12',
#   'GNG13',
#   'GCG',
#   'GNG11',
#   'GNAS',
#   'GNG8',
#   'SCT',
#   'GNB4',
#   'GPR123',
#   'GNB5',
#   'GNB2',
#   'BAIAP3',
#   'GNG3',
#   'GNG7',
#   'GNB1',
#   'GNG2',
#   'GNG10',
#   'GNG5',
#   'GNGT2',
#   'GHRH',
#   'GNB3'],
#  'RALBP1': ['RRAS2',
#   'CDK1',
#   'GPS2',
#   'REPS2',
#   'AP2M1',
#   'CDC42',
#   'RAC2',
#   'KDELR3',
#   'AAK1',
#   'COPA',
#   'NRAS',
#   'KRAS',
#   'ARF6',
#   'RAC1',
#   'REPS1',
#   'KDELR2',
#   'RALA',
#   'IKBKG',
#   'CYTH2',
#   'MRAS',
#   'CLTB',
#   'AP2A1',
#   'EXOC2',
#   'BMP2K',
#   'KDELR1',
#   'RALGDS',
#   'TRAF2',
#   'CLTA',
#   'ARF1',
#   'CCNB1',
#   'RRAS',
#   'HRAS',
#   'EXOC8',
#   'HSP90AA1',
#   'RALB',
#   'RHOA',
#   'SYNJ2BP',
#   'EPN1',
#   'RAC3'],
#  'PSD': ['KCNK1',
#   'ARF1',
#   'LYRM2',
#   'PTDSS1',
#   'ACAP1',
#   'CRLS1',
#   'CHST15',
#   'ACTN1',
#   'PISD',
#   'ARF6'],
#  'SYT13': ['NRXN1',
#   'NCF2',
#   'RALA',
#   'ESYT3',
#   'UNC13B',
#   'TMEM233',
#   'SNAP25',
#   'UNC13A',
#   'SYN2',
#   'SYN3',
#   'VAMP2',
#   'EPHA4',
#   'PRRT2',
#   'VAMP1',
#   'ESYT2',
#   'RTN1',
#   'SYTL1',
#   'STX1A',
#   'SYN1',
#   'ESYT1',
#   'RPS3',
#   'SNAP23'],
#  'SLC7A9': ['SLC7A10',
#   'SLC1A2',
#   'SLC7A5',
#   'SLC1A7',
#   'SHROOM3',
#   'SLC7A7',
#   'SLC17A1',
#   'SLC6A20',
#   'SLC6A19',
#   'SLC3A2',
#   'BSG',
#   'HOGA1',
#   'SLC1A1',
#   'SLC7A6',
#   'SLC6A14',
#   'AIRE',
#   'SLC7A11',
#   'SLC3A1',
#   'SLC7A8'],
#  'RTFDC1': ['CTSZ',
#   'CCDC130',
#   'PPP4R1',
#   'RBM25',
#   'SNRPF',
#   'LARS',
#   'TRMT1',
#   'RPAP2',
#   'SMU1',
#   'PKIG',
#   'CSTF1',
#   'DOK5',
#   'ABL1',
#   'RTF1',
#   'ATP9B',
#   'FAM209A'],
#  'RB1CC1': ['SQSTM1',
#   'ATG13',
#   'ATG9A',
#   'GABARAPL1',
#   'ULK2',
#   'AKT1S1',
#   'TSC1',
#   'RPTOR',
#   'PRKAB2',
#   'ATG4A',
#   'PRKAB1',
#   'PTK2',
#   'SMARCB1',
#   'MAP1LC3C',
#   'ATG16L2',
#   'CD300C',
#   'LAMTOR4',
#   'DYNLL1',
#   'TP53',
#   'TAX1BP1',
#   'C9orf72',
#   'VAPA',
#   'TRAF2',
#   'GABARAPL2',
#   'ATG14',
#   'PIK3R4',
#   'LAMTOR5',
#   'SLC38A9',
#   'PIK3C3',
#   'MTOR',
#   'PRKAG1',
#   'MAP1LC3A',
#   'ATG101',
#   'ATG4D',
#   'ATG12',
#   'WDR41',
#   'LAMTOR1',
#   'ATG16L1',
#   'RRAGC',
#   'MLST8',
#   'BECN1',
#   'TBKBP1',
#   'RRAGD',
#   'CALCOCO2',
#   'ATG5',
#   'PRKAG2',
#   'SMCR8',
#   'OPTN',
#   'ULK1',
#   'STMN1',
#   'DYNLL2',
#   'ATG10',
#   'MAP1LC3B',
#   'ATG7',
#   'PRKAG3',
#   'PREB',
#   'FGF12',
#   'AMBRA1',
#   'GABARAP',
#   'PRKAA2',
#   'RRAGB',
#   'WIPI1',
#   'ATG2A',
#   'PTK2B',
#   'RHEB',
#   'PRKAA1',
#   'ULK3',
#   'RPS6KB1',
#   'RFWD2',
#   'CHMP4B',
#   'CCPG1',
#   'UVRAG',
#   'WDR45',
#   'ATG4B',
#   'LAMTOR3',
#   'RAB7A',
#   'LAMTOR2',
#   'WIPI2',
#   'NBR1',
#   'VAPB',
#   'BRINP2',
#   'PINK1',
#   'ATG3',
#   'ATG4C',
#   'TSC2',
#   'ZFYVE1',
#   'NRBF2',
#   'ATG2B',
#   'TBK1',
#   'STX17',
#   'STXBP2',
#   'RRAGA'],
#  'AKAP11': ['FAM216B',
#   'IQGAP2',
#   'GPC5',
#   'TNK1',
#   'PRKAR2A',
#   'AKAP5',
#   'IRX2',
#   'PPP1CC',
#   'IQGAP3',
#   'PRKAR2B',
#   'IQGAP1',
#   'AKAP2',
#   'AKAP7',
#   'PRKAR1A',
#   'AKAP8',
#   'PRKACB',
#   'IRX3',
#   'GSK3B',
#   'PALM2AKAP2',
#   'AKAP9',
#   'AKAP1',
#   'IRX4',
#   'IRX1',
#   'DNAJC15',
#   'AKAP13'],
#  'PIGQ': ['TMEM183A',
#   'PIGA',
#   'PIGY',
#   'PYURF',
#   'DPM1',
#   'PIGL',
#   'ST3GAL5',
#   'GPI',
#   'PIGO',
#   'MPDU1',
#   'PIGB',
#   'SLC25A3',
#   'PIGH',
#   'PIGZ',
#   'PIGT',
#   'PIGG',
#   'CDIPT',
#   'PIGV',
#   'PIGW',
#   'PGAP3',
#   'PIGM',
#   'PGAP2',
#   'MAN2A1',
#   'PIGC',
#   'GPAA1',
#   'DPM2',
#   'PIGP',
#   'ATP1B2',
#   'PIGN',
#   'PIGK'],
#  'CDH17': ['CDON',
#   'CDH26',
#   'CTNND2',
#   'CDH15',
#   'DSP',
#   'MYC',
#   'DCHS1',
#   'CDH19',
#   'NOTCH1',
#   'TCF15',
#   'CDH20',
#   'CTTN',
#   'ZEB1',
#   'JUP',
#   'RHOA',
#   'CAV1',
#   'OLFM4',
#   'CDH7',
#   'PKP2',
#   'FECH',
#   'GPR148',
#   'ITGB1',
#   'MLLT4',
#   'CTNNA3',
#   'KLRG1',
#   'CDH18',
#   'CDH5',
#   'CLSTN1',
#   'VEZT',
#   'AKT1',
#   'CDH6',
#   'ERBB2',
#   'SRC',
#   'PTPRM',
#   'LGALS3',
#   'CDHR3',
#   'ANPEP',
#   'LTBP3',
#   'PKP3',
#   'CDH23',
#   'CDH9',
#   'ARHGEF17',
#   'CTNNA2',
#   'FN1',
#   'ARVCF',
#   'SNAI1',
#   'PVRL1',
#   'CDH8',
#   'CDH2',
#   'CDH3',
#   'TP53',
#   'CTNNA1',
#   'EGFR',
#   'LRP5',
#   'ITGAE',
#   'ABCC2',
#   'SLC12A3',
#   'CDH13',
#   'APC',
#   'CTNND1',
#   'IQGAP1',
#   'OCLN',
#   'CTNNB1',
#   'NEO1',
#   'LIMA1',
#   'PSEN1',
#   'ELOVL6',
#   'CDH22',
#   'EGF',
#   'PTPRS',
#   'PTK2',
#   'CDH12',
#   'CDH1',
#   'SNAI2',
#   'PECAM1',
#   'ANXA2',
#   'VCL',
#   'GJA1',
#   'CDC42',
#   'HNF4A',
#   'KDR',
#   'CDH4',
#   'PKP1',
#   'PKP4',
#   'ARHGAP35',
#   'PTPN1',
#   'CLSTN2',
#   'SHC1',
#   'AXIN1',
#   'CDH10',
#   'CDH11',
#   'TJP1',
#   'VEGFA'],
#  'B4GALT7': ['SLC39A13',
#   'UXS1',
#   'RPN1',
#   'GPC6',
#   'DCN',
#   'PLOD1',
#   'SDC4',
#   'GPC2',
#   'NCAN',
#   'GPC1',
#   'GPC5',
#   'EXTL2',
#   'B3GAT1',
#   'ST3GAL2',
#   'CHST14',
#   'GPC3',
#   'B3GALNT2',
#   'B3GAT3',
#   'ZFAT',
#   'AGRN',
#   'XYLT2',
#   'SLC35B2',
#   'FKBP14',
#   'PTAR1',
#   'SFXN5',
#   'CSPG4',
#   'BGN',
#   'XYLT1',
#   'BCAN',
#   'SDC1',
#   'GPC4',
#   'VCAN',
#   'CSPG5',
#   'EXTL3',
#   'SDC2',
#   'CANT1',
#   'B3GALT6',
#   'CHSY1',
#   'SDC3',
#   'HSPG2',
#   'CSGALNACT1'],
#  'FAM13B': ['C11orf45', 'RUFY1', 'SLC4A7', 'METTL11B', 'RASGEF1C', 'MYOZ1'],
#  'CHPF2': ['CHPF',
#   'MAN2C1',
#   'CHSY3',
#   'DCN',
#   'NCOA1',
#   'NCAN',
#   'EOGT',
#   'VCAN',
#   'B3GALT2',
#   'CSPG5',
#   'CSGALNACT1',
#   'ARGLU1',
#   'CHSY1',
#   'CSGALNACT2',
#   'B3GAT3',
#   'CSPG4',
#   'BGN',
#   'XYLT1',
#   'BCAN'],
#  'LRRC7': ['GRIA3',
#   'CCDC17',
#   'GRIA1',
#   'SRC',
#   'DLG1',
#   'KRAS',
#   'DLG3',
#   'CNKSR2',
#   'DLG4',
#   'ZIC4',
#   'CAMK2A',
#   'CTNND2',
#   'SHANK1',
#   'TOR1A',
#   'ACTN4',
#   'DLG2',
#   'GRIA2',
#   'GRIA4',
#   'GRIN2D',
#   'GRIN2C',
#   'SHANK2',
#   'SYNGAP1',
#   'PKP4',
#   'NRAS',
#   'GRIN2B',
#   'CAMK2G',
#   'GRIN1',
#   'TMEM69',
#   'LGI3',
#   'CACNA1D',
#   'NPHS1',
#   'HRAS',
#   'GRIN2A',
#   'ERBB4',
#   'GPBP1L1',
#   'ACTN2'],
#  'GABARAPL2': ['ATG12',
#   'ATG4D',
#   'GABRB3',
#   'GABRG3',
#   'PLEKHM1',
#   'GABARAP',
#   'WIPI1',
#   'GABRP',
#   'FAM134B',
#   'GABRA2',
#   'VTI1B',
#   'GABRA6',
#   'ATG7',
#   'ATG10',
#   'CHMP6',
#   'SIRT1',
#   'ATG5',
#   'UFM1',
#   'TECPR2',
#   'MLX',
#   'CHMP2A',
#   'PEX10',
#   'WDFY3',
#   'CHMP4B',
#   'TP53INP2',
#   'TBC1D17',
#   'TECPR1',
#   'ATG2B',
#   'RAB7B',
#   'ATG3',
#   'TP53INP1',
#   'UBQLN1',
#   'PINK1',
#   'GOSR1',
#   'VMP1',
#   'PRKACB',
#   'CTSF',
#   'ATG9A',
#   'GABRD',
#   'BNIP3',
#   'SQSTM1',
#   'ATG13',
#   'GABRA4',
#   'BCL2L13',
#   'GABRB1',
#   'ATG16L2',
#   'PARK2',
#   'RB1CC1',
#   'LAMP1',
#   'NEDD8',
#   'HTT',
#   'GABRA3',
#   'CD300C',
#   'NEDD4',
#   'MTOR',
#   'GABRA1',
#   'GIMAP6',
#   'GABRB2',
#   'PIK3C3',
#   'FYCO1',
#   'BECN1',
#   'TBC1D25',
#   'ATG16L1',
#   'ATG101',
#   'GABRQ',
#   'AMBRA1',
#   'MAP1LC3B',
#   'ULK1',
#   'OPTN',
#   'CALCOCO2',
#   'NBR1',
#   'WIPI2',
#   'ATG4B',
#   'RAB7A',
#   'UVRAG',
#   'STBD1',
#   'ULK3',
#   'ATG2A',
#   'CHMP4A',
#   'UBA3',
#   'STX17',
#   'BNIP3L',
#   'ZFYVE1',
#   'ATG4C',
#   'CHMP7',
#   'UBA5',
#   'GABRE',
#   'TEX264',
#   'GABRG1',
#   'ULK2',
#   'EXOC7',
#   'FUNDC1',
#   'LAMP2',
#   'GABARAPL1',
#   'NSFL1C',
#   'MAP1LC3C',
#   'TBC1D15',
#   'ATG4A',
#   'TBC1D5',
#   'PSMD4',
#   'TBC1D9B',
#   'CHMP4C',
#   'TAX1BP1',
#   'URM1',
#   'TUBA4A',
#   'GABRA5',
#   'PRKACG',
#   'TMEM184A',
#   'MAP1LC3A',
#   'TMEM184B',
#   'CHMP2B',
#   'GPR37',
#   'PRKACA',
#   'ARF1',
#   'PIK3R4',
#   'ATG14'],
#  'MYOC': ['GPR143',
#   'MYL2',
#   'SNCG',
#   'METTL13',
#   'PRRC2C',
#   'PPAPDC2',
#   'FOXC1',
#   'OPTN',
#   'FN1',
#   'NR2E3',
#   'CRYBB1',
#   'NTF4',
#   'LINGO1',
#   'FBLN2',
#   'SPARCL1',
#   'ANGPTL7',
#   'TMCO1',
#   'GAPDH',
#   'WIF1',
#   'TMTC1',
#   'LTBP2',
#   'CALR',
#   'PXDN',
#   'CYP1B1',
#   'ASB10',
#   'HSP90B1',
#   'WDR36',
#   'PEX5',
#   'FLOT1'],
#  'FAM136A': ['EXOSC5', 'ACSM3', 'PRMT5', 'SPTBN5', 'MMD2', 'DTNA'],
#  'OTC': ['ARG2',
#   'OTP',
#   'H6PD',
#   'TIMM44',
#   'NOS3',
#   'HSPA9',
#   'TIMM17B',
#   'ALDH18A1',
#   'PMPCB',
#   'GBE1',
#   'NAGS',
#   'ACY1',
#   'TIMM21',
#   'CAD',
#   'PAM16',
#   'GRPEL2',
#   'PITRM1',
#   'GRPEL1',
#   'NOS2',
#   'CPS1',
#   'TIMM23',
#   'TIMM50',
#   'PMPCA',
#   'ODC1',
#   'ARG1',
#   'DNAJC19',
#   'ENSG00000249319',
#   'ASL',
#   'OAT',
#   'UMPS',
#   'TIMM17A',
#   'ASS1',
#   'NOS1'],
#  'TTC17': ['RBM33'],
#  'HOXC8': ['ASXL2',
#   'SMAD6',
#   'HOXC6',
#   'ZFHX4',
#   'ASXL3',
#   'CXorf67',
#   'PBX1',
#   'PCDH19',
#   'HOMEZ',
#   'SMAD1',
#   'HOXC9',
#   'TAPT1'],
#  'MRI1': ['KCTD3',
#   'APIP',
#   'TMEM95',
#   'RBM34',
#   'POLR1B',
#   'LRRC40',
#   'SRM',
#   'C7orf49',
#   'MTAP',
#   'APRT',
#   'ENOPH1',
#   'ADI1',
#   'CCDC130',
#   'PES1',
#   'FAM181A',
#   'TMEM9'],
#  'BOD1L1': ['ALPK3',
#   'BRCA2',
#   'CHD8',
#   'MSS51',
#   'RAB28',
#   'FBXO18',
#   'BPTF',
#   'ATP8B2',
#   'CEP112',
#   'WHSC1L1',
#   'SETD1A',
#   'TTC29',
#   'DNA2',
#   'WDR5',
#   'WRNIP1',
#   'SMARCAL1',
#   'CXorf57',
#   'CXXC1',
#   'FAM175B',
#   'TNS3',
#   'EXO1'],
#  'TARBP1': ['TRMT1',
#   'RBM8A',
#   'NUCKS1',
#   'ALKBH8',
#   'TRMT10A',
#   'TRUB1',
#   'UTP20',
#   'PUS3',
#   'CCDC129',
#   'TRMT5',
#   'TRMT10B',
#   'EEF1A1',
#   'POLR1A',
#   'APBA2',
#   'APBA3',
#   'HTATIP2',
#   'TRMT13',
#   'TRMT6',
#   'NSUN2',
#   'METTL1',
#   'CCT4',
#   'TRMT44',
#   'APBB1',
#   'TRMT11',
#   'DUS2',
#   'TARBP2',
#   'FTSJ1'],
#  'RTN4R': ['EMG1',
#   'RHOH',
#   'ANPEP',
#   'TNF',
#   'CHMP1A',
#   'SMTN',
#   'NGFR',
#   'SMTNL1',
#   'TNFSF13B',
#   'TNFRSF19',
#   'SORT1',
#   'LINGO1',
#   'KIAA0319L',
#   'ZDHHC8',
#   'OMG',
#   'RTN1',
#   'RHOA',
#   'MAG',
#   'RTN4',
#   'MT-ND1',
#   'LILRB3',
#   'APP',
#   'PTPRS',
#   'ARHGDIA'],
#  'PSMA4': ['TP73',
#   'PSMA2',
#   'HSP90AA1',
#   'ACAD8',
#   'OAZ1',
#   'RUNX3',
#   'SOD1',
#   'CDC6',
#   'HSPA4',
#   'PRNP',
#   'PSMD11',
#   'PSMB2',
#   'NUMB',
#   'PSMD10',
#   'CHRNA3',
#   'RPN1',
#   'NEDD8',
#   'HTT',
#   'TXNL1',
#   'PSMA8',
#   'EIF3G',
#   'ASNA1',
#   'PARK2',
#   'NFKB1',
#   'RELA',
#   'SNRPD3',
#   'PSMB4',
#   'PSMC6',
#   'LSM3',
#   'EEF1B2',
#   'RPL9',
#   'ORC1',
#   'EIF3I',
#   'PSMC4',
#   'PSMA5',
#   'PFDN4',
#   'RPSA',
#   'PSMB9',
#   'EEF1A1',
#   'PSMD3',
#   'FBXL7',
#   'RPS4X',
#   'CHRNA5',
#   'PSME2',
#   'C14orf166',
#   'PSMD9',
#   'SUFU',
#   'DPM1',
#   'PSMC5',
#   'MAPK6',
#   'COPS5',
#   'KIAA2012',
#   'GLI1',
#   'ELP6',
#   'PSMD14',
#   'NUB1',
#   'PSMB11',
#   'PSMB7',
#   'GMNN',
#   'OAZ2',
#   'PTEN',
#   'RPS20',
#   'ATAD2B',
#   'NFKBIA',
#   'UBA52',
#   'PSMA7',
#   'GNB2L1',
#   'SNRPF',
#   'UBFD1',
#   'ERH',
#   'UBB',
#   'RFWD2',
#   'PSME1',
#   'CAPN11',
#   'CCND1',
#   'IREB2',
#   'CCT2',
#   'HNRNPD',
#   'ACADM',
#   'RPL26',
#   'PSMD8',
#   'PSMD5',
#   'SPATA5L1',
#   'PSME4',
#   'ADRM1',
#   'PSMC1',
#   'CCT3',
#   'PSMD7',
#   'GLI3',
#   'MPND',
#   'HSPE1',
#   'BRCC3',
#   'CCT4',
#   'UBE2N',
#   'PSMB8',
#   'RPN2',
#   'PHF5A',
#   'SHH',
#   'PSMD1',
#   'VCP',
#   'CCT8',
#   'KPNB1',
#   'PFDN2',
#   'SNCA',
#   'PSMD4',
#   'SNRPD2',
#   'ENY2',
#   'SPRED3',
#   'PAK2',
#   'RUVBL1',
#   'GLI2',
#   'PFDN5',
#   'PSMG2',
#   'SHFM1',
#   'PSME3',
#   'PSMD13',
#   'UCHL5',
#   'CFTR',
#   'RPS16',
#   'UBD',
#   'PSMA6',
#   'UBBP4',
#   'ODC1',
#   'PSMB3',
#   'OAZ3',
#   'LSM5',
#   'RAN',
#   'SNRPG',
#   'UBE2V2',
#   'NF1',
#   'POMP',
#   'NOTCH4',
#   'PSMA1',
#   'PSMB1',
#   'PRICKLE1',
#   'MYSM1',
#   'PSMC2',
#   'CCT5',
#   'PSMG1',
#   'PSMB6',
#   'PFDN6',
#   'RPS27A',
#   'CHRNB4',
#   'CCT7',
#   'VBP1',
#   'EIF3B',
#   'PSMD2',
#   'EIF2S3',
#   'CDC25A',
#   'SSB',
#   'PSMD12',
#   'UBC',
#   'PLAA',
#   'SPRED2',
#   'PSMB10',
#   'PSMC3',
#   'CCT6A',
#   'PSMA3',
#   'PFDN1',
#   'AIMP1',
#   'TCP1',
#   'MAP3K14',
#   'PSMD6',
#   'USP14',
#   'ITCH',
#   'EEF2',
#   'STIP1',
#   'UBLCP1',
#   'ETF1',
#   'UBE3A',
#   'SPATA5',
#   'RUNX2',
#   'HYKK',
#   'SPRED1',
#   'PSMB5',
#   'RBX1',
#   'PSMF1'],
#  'ZPBP': ['SPATA16',
#   'ACRBP',
#   'FIGNL1',
#   'ZAN',
#   'ODF3',
#   'TSACC',
#   'C7orf72',
#   'DPY19L2',
#   'VWC2',
#   'GRB7',
#   'HESX1',
#   'SPACA1',
#   'RBM44',
#   'ZPBP2',
#   'THEGL',
#   'ZP2',
#   'SPA17',
#   'CFAP61',
#   'CEP55'],
#  'LCP2': ['BLK',
#   'HCK',
#   'CD53',
#   'CD28',
#   'CTSS',
#   'PRKCQ',
#   'PIK3CB',
#   'HLA-DPA1',
#   'BIN2',
#   'HLA-DRA',
#   'CARD11',
#   'WAS',
#   'PTPN11',
#   'FCER1A',
#   'CRKL',
#   'IGSF6',
#   'ITGB2',
#   'CD3E',
#   'KLRC2',
#   'VAV1',
#   'LAPTM5',
#   'SPI1',
#   'CST7',
#   'LYN',
#   'RAC1',
#   'SKAP1',
#   'SYK',
#   'CD79A',
#   'CYTIP',
#   'FCER1G',
#   'IGHV3-11',
#   'IKZF1',
#   'NCK1',
#   'UBASH3A',
#   'MS4A2',
#   'PARVG',
#   'SHC1',
#   'HLA-A',
#   'GPR174',
#   'BLNK',
#   'HLA-E',
#   'CSF2RB',
#   'CBL',
#   'ARHGAP25',
#   'PECAM1',
#   'CTLA4',
#   'EVL',
#   'TRAF3IP3',
#   'LAT',
#   'PIK3R2',
#   'ITK',
#   'UBASH3B',
#   'CD6',
#   'BTK',
#   'CSF1R',
#   'SPN',
#   'SOS1',
#   'MAP4K1',
#   'BCL2A1',
#   'MAP3K1',
#   'CD247',
#   'CD48',
#   'CYTH4',
#   'AKT1',
#   'INPP5D',
#   'CD4',
#   'CD2',
#   'PTPN6',
#   'LAT2',
#   'MRVI1',
#   'RAC2',
#   'DBNL',
#   'GAD1',
#   'ENAH',
#   'DOCK2',
#   'GRAP',
#   'CDC42',
#   'CD3G',
#   'SRC',
#   'CD3D',
#   'LY9',
#   'FYB',
#   'PTPRC',
#   'RANGAP1',
#   'LRRC9',
#   'B2M',
#   'GRAP2',
#   'CD8B',
#   'HLA-DRB1',
#   'AIF1',
#   'PIK3CG',
#   'EVI2B',
#   'PLCG1',
#   'IL10RA',
#   'IL7R',
#   'CD69',
#   'NCK2',
#   'GRB2',
#   'FYN',
#   'LCK',
#   'CRK',
#   'TREM2',
#   'CD8A',
#   'HLA-DQA1',
#   'PAK2',
#   'KLRD1',
#   'IL2RG',
#   'CCR1',
#   'PAK3',
#   'PIK3R1',
#   'GP6',
#   'RAP1B',
#   'TYROBP',
#   'IGLL5',
#   'KLHL6',
#   'CCL4',
#   'PDPN',
#   'APBB1IP',
#   'MAP3K7',
#   'HLA-DQB2',
#   'TXK',
#   'PSTPIP1',
#   'EGFR',
#   'RASGRP1',
#   'PTPN22',
#   'CD101',
#   'FGR',
#   'PAK1',
#   'HLA-DQB1',
#   'PIK3CA',
#   'HLA-DRB5',
#   'TAGAP',
#   'GNS',
#   'CD80',
#   'VASP',
#   'CLEC1B',
#   'MPEG1',
#   'INPPL1',
#   'HLA-DQA2',
#   'IL2RB',
#   'HCST',
#   'PLCG2',
#   'HLA-DPB1',
#   'RAP1A',
#   'CD22',
#   'TLR4',
#   'TEC',
#   'ZAP70',
#   'GIMAP5',
#   'HCLS1',
#   'VAV3',
#   'PLEK',
#   'VAV2'],
#  'DCN': ['B3GAT2',
#   'EGF',
#   'VCAN',
#   'CHSY1',
#   'PDGFRA',
#   'SPARC',
#   'DPT',
#   'CSGALNACT1',
#   'COL14A1',
#   'CHST9',
#   'SPP1',
#   'COMP',
#   'COL3A1',
#   'CHST3',
#   'ERBB4',
#   'GPC4',
#   'XYLT1',
#   'B3GAT1',
#   'MFAP2',
#   'CHPF',
#   'HAL',
#   'ACAN',
#   'DDR2',
#   'UST',
#   'POSTN',
#   'CHST11',
#   'EGFR',
#   'B4GALT7',
#   'FLNA',
#   'DSE',
#   'IBSP',
#   'MFAP4',
#   'MATN2',
#   'COL1A1',
#   'SDC3',
#   'B3GALT6',
#   'TIMP3',
#   'MMP14',
#   'AHSG',
#   'MSTN',
#   'TLR2',
#   'MET',
#   'SDC1',
#   'CHST15',
#   'FBN1',
#   'TGFBI',
#   'BGLAP',
#   'TGFB1',
#   'LUM',
#   'KDR',
#   'COL6A3',
#   'GPC6',
#   'SDC4',
#   'TNMD',
#   'IGF1',
#   'VWF',
#   'FGF2',
#   'GPC1',
#   'GPC5',
#   'MMP7',
#   'YBX1',
#   'GPC2',
#   'COL5A1',
#   'CHPF2',
#   'CTGF',
#   'MATN1',
#   'FBLN1',
#   'HSPG2',
#   'CXCL12',
#   'CHST12',
#   'AGRN',
#   'MMP2',
#   'XYLT2',
#   'TMPRSS6',
#   'TLR4',
#   'C1R',
#   'TGFB3',
#   'CHSY3',
#   'NCAN',
#   'IGF1R',
#   'ELN',
#   'FN1',
#   'MMP13',
#   'YBX3',
#   'SDC2',
#   'DSEL',
#   'ERBB3',
#   'B3GAT3',
#   'CSGALNACT2',
#   'BCAN',
#   'THBS1',
#   'CHST13',
#   'LRP1',
#   'CSPG4',
#   'COL6A1',
#   'COL1A2',
#   'TGFB2',
#   'CHST14',
#   'KLHL17',
#   'ERBB2',
#   'NID1',
#   'GPC3',
#   'SFTPD',
#   'LEPREL2',
#   'RETN',
#   'CHST7',
#   'MMP3',
#   'WISP1'],
#  'TNFRSF17': ['TNFSF13',
#   'IGJ',
#   'C1QB',
#   'TRAF5',
#   'CD38',
#   'CD19',
#   'FURIN',
#   'TNFRSF13B',
#   'POU2AF1',
#   'TRAF6',
#   'TNFSF13B',
#   'MZB1',
#   'TNFRSF13C',
#   'TRAF3'],
#  'MRPS10': ['RPL36A',
#   'RPL7',
#   'RPL37A',
#   'RPL36AL',
#   'WDR31',
#   'RPL3',
#   'RPL4',
#   'RPL24',
#   'RSL24D1',
#   'RPL8',
#   'MRPS14',
#   'NPSR1',
#   'RPL22',
#   'HSPE1',
#   'RPL36A-HNRNPH2',
#   'MRPL32',
#   'RPS2',
#   'EPRS',
#   'MRPL10',
#   'MRPL41',
#   'ENSG00000239789',
#   'MTIF2',
#   'GADD45GIP1',
#   'RPL19',
#   'MRPS7',
#   'RPS12',
#   'RPL6',
#   'MRPS25',
#   'IMP3',
#   'RPS5',
#   'TUFM',
#   'RPS27',
#   'MRPL24',
#   'MRPS5',
#   'MRPL11',
#   'RPL17',
#   'MRPL20',
#   'RPL22L1',
#   'RPLP1',
#   'MRPS30',
#   'MRPL3',
#   'RPSAP58',
#   'RPL15',
#   'MRPS35',
#   'TSFM',
#   'RPL27',
#   'EFTUD2',
#   'RPL17-C18orf32',
#   'RPS26',
#   'RPL35A',
#   'MRPS11',
#   'RPS17',
#   'RPS19',
#   'EIF3G',
#   'POLR2F',
#   'RPS25',
#   'EIF5B',
#   'MRPL40',
#   'HSPBP1',
#   'MRPL43',
#   'RPL28',
#   'RPL36',
#   'RPS16',
#   'MRPL48',
#   'MRPL38',
#   'RPS28',
#   'MRPL13',
#   'MRPL53',
#   'NSA2',
#   'MRPL14',
#   'MRPL42',
#   'MRPL46',
#   'EFTUD1',
#   'MRPL12',
#   'RPL30',
#   'MRPL37',
#   'POLR2C',
#   'RPMS17',
#   'ENSG00000260342',
#   'RPL12',
#   'RPS7',
#   'RPL32',
#   'RPS6',
#   'MRPL1',
#   'RPL9',
#   'CARS',
#   'MRRF',
#   'RPL13A',
#   'PTCD3',
#   'SEC61A1',
#   'RPL14',
#   'MRPS6',
#   'PLEC',
#   'MRPL34',
#   'RPS3',
#   'RPS27L',
#   'MOV10',
#   'SMKR1',
#   'TOMM7',
#   'RPL13',
#   'RPL23A',
#   'RPL3L',
#   'ENSG00000262660',
#   'MRPL30',
#   'EIF1AX',
#   'GFM2',
#   'RPS11',
#   'RPL10',
#   'SOD2',
#   'RPS14',
#   'RPS15A',
#   'RPS21',
#   'MRPL54',
#   'MRPS18B',
#   'MRPS18C',
#   'MRPL36',
#   'MRPL18',
#   'RPS4X',
#   'RPS15',
#   'EIF3J',
#   'TFB2M',
#   'PDCD11',
#   'MRPL50',
#   'MRPL27',
#   'RPS10-NUDT3',
#   'RPSA',
#   'MRPS16',
#   'MRPS21',
#   'CHCHD1',
#   'C18orf32',
#   'MRPL55',
#   'MRPL51',
#   'RPL31',
#   'MRPL35',
#   'RPL34',
# ...
#   'COPS4',
#   'REL',
#   'LMO7',
#   'FBXO27',
#   'FBXL19',
#   'CDC25A',
#   'FAF1',
#   'TNIP2',
#   'TCEB1',
#   'KDM2B',
#   'ZNF346',
#   'FBXW10',
#   'MAMLD1'],
#  'NUP155': ['IPO7',
#   'CPSF3',
#   'HNRNPC',
#   'SNRPB',
#   'HSPA5',
#   'CPSF4',
#   'CPSF1',
#   'HSPA1B',
#   'HSPA4L',
#   'NUP98',
#   'GLE1',
#   'NEK7',
#   'NPM1',
#   'TNPO1',
#   'NUP160',
#   'SRRM1',
#   'RBM8A',
#   'NUP205',
#   'HSPA13',
#   'NUP210',
#   'HSPA2',
#   'NUP43',
#   'NUP54',
#   'NCBP2',
#   'UBE2I',
#   'EIF4E',
#   'CDK1',
#   'HSPA9',
#   'NUP62',
#   'NEK6',
#   'NUP88',
#   'SNRPF',
#   'AHCTF1',
#   'DDX20',
#   'MAGOH',
#   'KCNE2',
#   'CDCA8',
#   'NUP214',
#   'UPF3B',
#   'SEC13',
#   'C11orf73',
#   'GEMIN6',
#   'TNPO2',
#   'ALYREF',
#   'GATA5',
#   'HSPA12A',
#   'CASC3',
#   'BIRC5',
#   'KCNJ2',
#   'NUPL2',
#   'SEH1L',
#   'IPO8',
#   'SNUPN',
#   'RAE1',
#   'SUMO1',
#   'HSPA1A',
#   'NUP107',
#   'KPNB1',
#   'WDR33',
#   'GEMIN2',
#   'POLDIP3',
#   'NCBP1',
#   'CPSF6',
#   'C5orf42',
#   'HSPA8',
#   'NUP93',
#   'NUP50',
#   'CCNB2',
#   'NUP85',
#   'RFC4',
#   'GEMIN4',
#   'RANGAP1',
#   'SP100',
#   'HDAC4',
#   'RGPD2',
#   'NIPBL',
#   'WDR70',
#   'SLBP',
#   'IPO5',
#   'NUP62CL',
#   'SYMPK',
#   'ENSG00000251184',
#   'NUP35',
#   'NXF1',
#   'NDC1',
#   'HSPA14',
#   'MAGOHB',
#   'NXT1',
#   'SUMO3',
#   'AURKB',
#   'INCENP',
#   'HSPA6',
#   'NUP133',
#   'NEK9',
#   'NUP188',
#   'CSE1L',
#   'POM121',
#   'HSPA4',
#   'SNRPD2',
#   'FIP1L1',
#   'EIF4A3',
#   'GEMIN8',
#   'EFTUD2',
#   'PHAX',
#   'SNRPE',
#   'SLC1A3',
#   'TNPO3',
#   'TOP2A',
#   'NUP153',
#   'NUP210L',
#   'NUP37',
#   'GEMIN5',
#   'AAAS',
#   'MDM2',
#   'AGO2',
#   'SNRPD1',
#   'CPSF2',
#   'TPR',
#   'HSPA12B',
#   'XPO1',
#   'SUMO2',
#   'GCK',
#   'NUPL1',
#   'KCNA5',
#   'NCOA5',
#   'RANBP2',
#   'CCNB1',
#   'GCKR',
#   'HSPA1L',
#   'SNRPG',
#   'PML',
#   'GEMIN7',
#   'RNPS1',
#   'SNRPD3',
#   'POM121C',
#   'RAN',
#   'XPOT'],
#  'NR3C1': ['PGR',
#   'NCOR1',
#   'AHR',
#   'SGK1',
#   'RETN',
#   'ARNTL',
#   'IRF7',
#   'TNF',
#   'GTF3C5',
#   'PIAS2',
#   'MEF2C',
#   'STIP1',
#   'AKT1',
#   'DCTN5',
#   'RUNX2',
#   'IRF3',
#   'SMARCC1',
#   'DAP3',
#   'GTF2B',
#   'HEXIM1',
#   'TXNRD2',
#   'PTGES3',
#   'BANF1',
#   'CEBPB',
#   'GTF2E1',
#   'GSK3B',
#   'STAT5A',
#   'RXRA',
#   'MAPK11',
#   'DUSP1',
#   'ANXA1',
#   'ESR1',
#   'IFNB1',
#   'NCL',
#   'DYNC1H1',
#   'TRIP6',
#   'IRF1',
#   'SMARCC2',
#   'ACTR1A',
#   'MC2R',
#   'BAG1',
#   'TSC22D3',
#   'STAT3',
#   'DYNLL1',
#   'PRKACG',
#   'CAPZB',
#   'SMAD4',
#   'DYNC1I2',
#   'EHMT2',
#   'SLC6A4',
#   'PIK3CA',
#   'SERPINA6',
#   'BDP1',
#   'DCTN4',
#   'PELP1',
#   'NF1',
#   'SMAD2',
#   'MED14',
#   'PRKACA',
#   'HSPA1L',
#   'DYNC1LI1',
#   'HSD11B2',
#   'GRIP1',
#   'IL6',
#   'HIF1A',
#   'IL1B',
#   'STUB1',
#   'INS',
#   'ACTB',
#   'CEBPA',
#   'PBX1',
#   'HSPA8',
#   'GTF3A',
#   'CALR',
#   'PM20D1',
#   'HIVEP3',
#   'HSPA1A',
#   'CAV1',
#   'PER2',
#   'POMC',
#   'MAPK9',
#   'NES',
#   'SMARCB1',
#   'ADIPOQ',
#   'DCTN1',
#   'DCTN3',
#   'FKBP5',
#   'NR3C2',
#   'TXN',
#   'KAT2B',
#   'ACTR10',
#   'UBE2I',
#   'BCL2A1',
#   'MAPK1',
#   'HSPA2',
#   'SMARCD1',
#   'GTF3C4',
#   'BDNF',
#   'NRIP1',
#   'POU2F1',
#   'GTF2A1',
#   'SUMO1',
#   'NTRK2',
#   'HSP90AB1',
#   'CBFB',
#   'FOXO3',
#   'CRY1',
#   'STAT5B',
#   'DAXX',
#   'HSPA1B',
#   'YWHAH',
#   'HDAC1',
#   'SFN',
#   'EPAS1',
#   'FOXO1',
#   'TGFB1I1',
#   'FOS',
#   'TWIST1',
#   'PTK6',
#   'CDK5R1',
#   'PPP1R3A',
#   'MED1',
#   'SMARCA4',
#   'HMGB1',
#   'IRF5',
#   'CRH',
#   'ARID1A',
#   'POU2F2',
#   'RARA',
#   'DYNLL2',
#   'TRIM63',
#   'PPARGC1B',
#   'IRF4',
#   'NCOA6',
#   'MAPK14',
#   'MAPK10',
#   'HDAC6',
#   'NCOA1',
#   'BRF1',
#   'EGFR',
#   'TP53',
#   'HDAC2',
#   'NCOR2',
#   'CAPZA3',
#   'BRCA1',
#   'HNRNPU',
#   'GTF3C3',
#   'PPARGC1A',
#   'PPP5C',
#   'NFKB1',
#   'RELA',
#   'CARM1',
#   'CAPZA1',
#   'DYNC1I1',
#   'WWP1',
#   'HSD11B1',
#   'CREB1',
#   'LGI2',
#   'ESRRA',
#   'PPID',
#   'CREBBP',
#   'POLR2A',
#   'DCTN2',
#   'STAT1',
#   'DYNC1LI2',
#   'SUMO2',
#   'IPO13',
#   'EGR1',
#   'DCAF6',
#   'MAPK3',
#   'KLF15',
#   'DCTN6',
#   'ATF2',
#   'SET',
#   'HSP90AA1',
#   'GTF3C1',
#   'AR',
#   'SKA2',
#   'PRKACB',
#   'NCOA3',
#   'IRF6',
#   'GTF2F1',
#   'JUN',
#   'NCOA2',
#   'TAT',
#   'LPL',
#   'SMARCA2',
#   'IRF2',
#   'HSPA4',
#   'PIK3R1',
#   'CRHR1',
#   'CRHR2',
#   'CAPZA2',
#   'MAPK8',
#   'FKBP4',
#   'SMARCE1',
#   'ALB',
#   'CRY2',
#   'SMAD3',
#   'EP300',
#   'CDK5'],
#  'TRIM23': ['RPS27A',
#   'CYTH2',
#   'UBC',
#   'UBE2D2',
#   'POTEB2',
#   'UBE2N',
#   'UBE2D4',
#   'UBE2D1',
#   'AP1AR',
#   'TRIM37',
#   'LRRK2',
#   'AP1G1',
#   'UBA52',
#   'TRAT1',
#   'IKBKG',
#   'CYTH1',
#   'UBB',
#   'TRIM29',
#   'TBK1',
#   'UBE2E1',
#   'LGALS8',
#   'TRIM55',
#   'TRIM8',
#   'TRIM27',
#   'UBE2D3',
#   'TRIM25'],
#  'RARS': ['VARS2',
#   'NCOR2',
#   'MARS',
#   'FARSA',
#   'CARS',
#   'RDH10',
#   'TARSL2',
#   'EXOSC6',
#   'ALDH1A3',
#   'JUN',
#   'MARS2',
#   'EPRS',
#   'TARS',
#   'SMAD3',
#   'CRABP2',
#   'DDX1',
#   'PPARA',
#   'PIK3R1',
#   'EIF2S2',
#   'FARSB',
#   'HARS2',
#   'WARS2',
#   'IARS',
#   'AARS2',
#   'GARS',
#   'CYP26A1',
#   'RXRG',
#   'ABCE1',
#   'PRAME',
#   'AIMP2',
#   'IARS2',
#   'PSMC5',
#   'RARA',
#   'PSMD14',
#   'RARG',
#   'RBP2',
#   'KARS',
#   'TARS2',
#   'METAP2',
#   'TRIM24',
#   'RARS2',
#   'LARS2',
#   'ALDH1A2',
#   'GPRC5A',
#   'NARS2',
#   'EARS2',
#   'DARS',
#   'LRRC47',
#   'CRABP1',
#   'SDCBP',
#   'LARS',
#   'VDR',
#   'EEF1E1',
#   'AARS',
#   'SAP30L',
#   'AIMP1',
#   'NCOR1',
#   'BRIX1',
#   'SARS2',
#   'RBP1',
#   'EIF2S1',
#   'CARS2',
#   'NARS',
#   'PPARG',
#   'FEZ2',
#   'RXRA',
#   'WARS',
#   'RXRB',
#   'EIF2S3',
#   'STRA6',
#   'CYP26B1',
#   'PARS2',
#   'HARS',
#   'CYP26C1',
#   'RARB',
#   'YARS2',
#   'YARS',
#   'TSR1',
#   'QARS',
#   'SARS'],
#  'CDX1': ['LHX4',
#   'NDST1',
#   'NR2C1',
#   'TCOF1',
#   'ANXA6',
#   'CTNNB1',
#   'SOX2',
#   'LEF1'],
#  'BNIP1': ['CREBRF',
#   'BNIP3',
#   'ZW10',
#   'KDELR3',
#   'STX16',
#   'STX1A',
#   'STX6',
#   'STX4',
#   'COPA',
#   'STX18',
#   'USE1',
#   'RAB1A',
#   'COPZ1',
#   'COPZ2',
#   'TMED3',
#   'SNX4',
#   'ATP6V0E1',
#   'STX10',
#   'SNAP29',
#   'NAPA',
#   'YKT6',
#   'COPE',
#   'VAMP1',
#   'KDELR2',
#   'STX7',
#   'SEC22B',
#   'SURF4',
#   'SCFD1',
#   'STX1B',
#   'VAMP3',
#   'CPLX2',
#   'MAP1LC3C',
#   'SNAP47',
#   'NBAS',
#   'STX12',
#   'COPG2',
#   'VTI1B',
#   'ICT1',
#   'STX3',
#   'VAMP2',
#   'BET1',
#   'STX11',
#   'NAPB',
#   'GOSR2',
#   'FAF2',
#   'STX19',
#   'VAMP8',
#   'STX2',
#   'RNF186',
#   'COPB1',
#   'VAMP4',
#   'SNAP23',
#   'STX8',
#   'SCFD2',
#   'CPLX1',
#   'VPS53',
#   'COPB2',
#   'ZNF787',
#   'BNIP2',
#   'STX5',
#   'RAB1B',
#   'KDELR1',
#   'ARCN1',
#   'SNAP25',
#   'RNF185',
#   'TMED10',
#   'TMED7',
#   'BCL2L1',
#   'TMED2',
#   'COPG1',
#   'TSNARE1',
#   'GOSR1',
#   'VTI1A',
#   'PIN4',
#   'NSF',
#   'TMED9',
#   'VAMP7',
#   'BET1L',
#   'NAPG',
#   'STX17',
#   'RINT1'],
#  'SLC7A14': ['EIF5A2', 'ANKS4B', 'RPL22L1', 'TNFAIP8'],
#  'SEMA3G': ['PLXNB1',
#   'VEGFA',
#   'PLXNB3',
#   'PLXND1',
#   'PLXNA4',
#   'NTN1',
#   'EPHA1',
#   'NRP1',
#   'PLXNA1',
#   'PLXNA3',
#   'NRP2'],
#  'ZMYND10': ['NPRL2',
#   'CCDC40',
#   'DNAH8',
#   'CCDC65',
#   'C21orf59',
#   'RSPH1',
#   'CCDC103',
#   'DNAI1',
#   'RUNX1T1',
#   'CCDC151',
#   'DNAH11',
#   'LRRC46',
#   'RSPH4A',
#   'PIH1D3',
#   'DNAH5',
#   'LRRC6',
#   'ARMC4',
#   'CDR2L',
#   'HEATR2',
#   'DRC1',
#   'DNAAF1',
#   'CCDC39',
#   'RASSF1',
#   'DNAI2',
#   'FAM187A',
#   'SPAG1',
#   'HYDIN',
#   'DNAAF3',
#   'DYX1C1',
#   'DNALI1',
#   'DNAAF2',
#   'RSPH9',
#   'NBEAL2',
#   'CCDC114'],
#  'LTF': ['ELANE',
#   'DEFA4',
#   'GC',
#   'LCN1',
#   'TCN1',
#   'TTR',
#   'SEMG1',
#   'LRP2',
#   'CST3',
#   'SERPINB3',
#   'FGA',
#   'SLC25A18',
#   'TFRC',
#   'EPPIN',
#   'ST6GALNAC1',
#   'AMBP',
#   'ALB',
#   'B2M',
#   'INS',
#   'WAP7',
#   'GSN',
#   'CEBPE',
#   'LDLRAP1',
#   'APOA1',
#   'GP9',
#   'APOA4',
#   'LYZ',
#   'MPO',
#   'SAA1',
#   'CLU',
#   'LCN2'],
#  'MLH1': ['NTHL1',
#   'DAPK1',
#   'HIST1H2BK',
#   'RUNX3',
#   'DCLRE1C',
#   'KPNA2',
#   'SMC3',
#   'CETN2',
#   'SMC1A',
#   'DMC1',
#   'NEUROG1',
#   'RFC4',
#   'ERCC8',
#   'UBOX5',
#   'HIST1H2BO',
#   'CDH1',
#   'XRCC4',
#   'ERCC4',
#   'XRCC1',
#   'HLTF',
#   'HIST1H2BH',
#   'XRCC3',
#   'STK11',
#   'BRCA1',
#   'TP53',
#   'EGFR',
#   'RAD9A',
#   'HRAS',
#   'CTNNB1',
#   'MSH6',
#   'POLH',
#   'RAD51',
#   'RAD51C',
#   'RPA3',
#   'CACNA1G',
#   'ABL1',
#   'FRMD6',
#   'ENSG00000267618',
#   'HIST3H3',
#   'ERCC1',
#   'XRCC5',
#   'PTEN',
#   'TIMP3',
#   'MSH3',
#   'RAD23B',
#   'MRE11A',
#   'ATM',
#   'MCM8',
#   'TGFBR2',
#   'RECQL4',
#   'ARID1A',
#   'LIG1',
#   'NBN',
#   'PCNA',
#   'RAD51D',
#   'LIG4',
#   'MUTYH',
#   'GEN1',
#   'SOCS1',
#   'MUS81',
#   'APBA1',
#   'BRIP1',
#   'HIST2H2BE',
#   'CCNB1IP1',
#   'PRKDC',
#   'SYCP3',
#   'SLX1B',
#   'NHEJ1',
#   'HIST1H2BJ',
#   'ZC3H11A',
#   'PMS2',
#   'HIST1H2BN',
#   'FAN1',
#   'CHEK1',
#   'RFC2',
#   'RPA2',
#   'XPC',
#   'DNA2',
#   'FEN1',
#   'HSPA8',
#   'SPO11',
#   'EPCAM',
#   'HIST1H2BL',
#   'KDM1A',
#   'DNMT1',
#   'MCM5',
#   'WRN',
#   'REEP5',
#   'FANCM',
#   'H2AFX',
#   'PMS1',
#   'CHEK2',
#   'OGG1',
#   'CRABP1',
#   'TRIP13',
#   'APEX1',
#   'MYC',
#   'HIST1H2BD',
#   'MLH3',
#   'TOP3A',
#   'PIK3CA',
#   'SMAD4',
#   'HIST1H2BM',
#   'ERCC2',
#   'EME1',
#   'FADD',
#   'CDK4',
#   'EXO1',
#   'RMI1',
#   'XRCC6',
#   'RAD54L',
#   'CDK2',
#   'SPERT',
#   'MSH5',
#   'CXorf57',
#   'PALB2',
#   'POLE',
#   'MGMT',
#   'XPA',
#   'RECQL',
#   'SLX1A',
#   'MSH4',
#   'APBA2',
#   'HIST1H2BB',
#   'KRAS',
#   'ERCC5',
#   'CDKN2A',
#   'BRCA2',
#   'MBD4',
#   'CASP3',
#   'CHFR',
#   'H2BFS',
#   'IGF2',
#   'UNG',
#   'MCM2',
#   'RAD51B',
#   'RAD52',
#   'POLD1',
#   'MSH2',
#   'FBXO18',
#   'ALDH18A1',
#   'ERCC3',
#   'SMC5',
#   'GSTP1',
#   'MND1',
#   'FHIT',
#   'ENSG00000142539',
#   'ATR',
#   'RPA1',
#   'RAD54B',
#   'BLM',
#   'BARD1',
#   'RASSF1',
#   'TEX11',
#   'HFM1',
#   'SMC4',
#   'MCM9',
#   'FANCD2',
#   'ERBB2',
#   'HIST1H2BA'],
#  'EHHADH': ['MCCC1',
#   'PEX13',
#   'NR1H3',
#   'EPHX2',
#   'PIPOX',
#   'MCCC2',
#   'CREBBP',
#   'DDO',
#   'RELA',
#   'PPARGC1A',
#   'GCDH',
#   'IRAK1',
#   'HMGCS1',
#   'NCOA1',
#   'DBT',
#   'EP300',
#   'ACSS1',
#   'HACL1',
#   'IDH1',
#   'ALDH3A2',
#   'PEX5',
#   'HIBADH',
#   'PPARA',
#   'HMGCL',
#   'LPL',
#   'ACAD11',
#   'JUN',
#   'PAOX',
#   'LONP2',
#   'SRA1',
#   'EIF2AK2',
#   'CITED2',
#   'ACAD8',
#   'ACSS3',
#   'OXCT1',
#   'DAO',
#   'ECH1',
#   'ALDH6A1',
#   'CRAT',
#   'PEX2',
#   'HAO1',
#   'APOA2',
#   'CPT1A',
#   'ECHS1',
#   'ACADM',
#   'NRIP1',
#   'TIRAP',
#   'ALDH9A1',
#   'PEX10',
#   'AGXT',
#   'AOX1',
#   'IDE',
#   'NUDT7',
#   'MPV17',
#   'ALDH1B1',
#   'IVD',
#   'PECR',
#   'PCCB',
#   'ECI1',
#   'ACOX1',
#   'TOLLIP',
#   'AMACR',
#   'MED1',
#   'ACAT2',
#   'OXCT2',
#   'BAAT',
#   'ACSL5',
#   'SP1',
#   'CROT',
#   'ACOT2',
#   'ABAT',
#   'ACOT4',
#   'NOS2',
#   'APOA1',
#   'CD14',
#   'PHYH',
#   'TLR4',
#   'ME1',
#   'ACSS2',
#   'DHRS4',
#   'ACSL1',
#   'HSD17B10',
#   'MYD88',
#   'DECR1',
#   'CPT2',
#   'GSTK1',
#   'PEX12',
#   'AGXT2',
#   'AACS',
#   'ACAA1',
#   'HMGCS2',
#   'CPT1B',
#   'GNPAT',
#   'HAO2',
#   'PCCA',
#   'PEX7',
#   'HADHA',
#   'ACAA2',
#   'ECI2',
#   'HIBCH',
#   'TYSND1',
#   'LY96',
#   'ACOX2',
#   'ALDH7A1',
#   'MLYCD',
#   'SCP2',
#   'FABP1',
#   'ALDH2',
#   'ACAT1',
#   'CAT',
#   'HSD17B4',
#   'ACOT8',
#   'ECHDC1',
#   'SLC27A2',
#   'DECR2',
#   'HADHB',
#   'ACADS',
#   'ACADL',
#   'NUDT19',
#   'ACOX3',
#   'ACADVL',
#   'RXRA',
#   'ACADSB',
#   'PEX14',
#   'ACOT1',
#   'HADH'],
#  'CRBN': ['RFWD2',
#   'CC2D1A',
#   'DDB2',
#   'VPRBP',
#   'ZNF692',
#   'PRSS12',
#   'CUL4B',
#   'ENSG00000132716',
#   'DCAF5',
#   'BTK',
#   'DDA1',
#   'DCAF11',
#   'DDB1',
#   'RBX1',
#   'GLUL',
#   'CDKN1B',
#   'FBXW5',
#   'DCAF13',
#   'RABGEF1',
#   'COPS4',
#   'DTL',
#   'SALL4',
#   'COPS8',
#   'CDT1',
#   'OTUD7B',
#   'TUSC3',
#   'COPS6',
#   'DCAF15',
#   'DCAF17',
#   'COPS5',
#   'IRF4',
#   'DET1',
#   'COPS7A',
#   'IKZF1',
#   'NEDD8',
#   'BRD4',
#   'AGO2',
#   'WDR42A',
#   'IKZF3',
#   'MBOAT7',
#   'GPS1',
#   'DCAF6',
#   'DCAF16',
#   'PSMB4',
#   'KCNMA1',
#   'GSPT1',
#   'DCAF12',
#   'ZNF2',
#   'CUL4A',
#   'DCAF10',
#   'JUN',
#   'ZFP91',
#   'CSNK1A1',
#   'DCAF4',
#   'COPS2',
#   'MEIS2',
#   'USP24',
#   'TRAF6',
#   'FBXO7',
#   'TRPC4AP',
#   'DCAF7',
#   'ERCC8',
#   'CLCN1',
#   'BSG',
#   'GLMN',
#   'COPS3'],
#  'HRG': ['ALDH8A1',
#   'APOB',
#   'SERPINA10',
#   'APOH',
#   'HGD',
#   'PAH',
#   'C8A',
#   'TM4SF4',
#   'AGXT',
#   'CPB2',
#   'PROZ',
#   'A2M',
#   'C7',
#   'FGA',
#   'F11',
#   'ITIH1',
#   'PLGLB2',
#   'APOA4',
#   'KLKB1',
#   'LPA',
#   'FGG',
#   'SPP2',
#   'SERPIND1',
#   'ORM2',
#   'ITIH3',
#   'TMPRSS6',
#   'PLAT',
#   'THBS1',
#   'ITIH2',
#   'A1CF',
#   'MBL2',
#   'F12',
#   'AFM',
#   'ORM1',
#   'FTCD',
#   'ANGPTL3',
#   'HPX',
#   'TTR',
#   'F13B',
#   'AHSG',
#   'NR1H4',
#   'FETUB',
#   'PLG',
#   'SERPINC1',
#   'FGB',
#   'AMBP',
#   'AMPD2',
#   'SERPINF2',
#   'GC',
#   'KNG1',
#   'PLAUR',
#   'F9',
#   'PROC',
#   'PLAU',
#   'PLGLB1',
#   'C3',
#   'VTN',
#   'HABP2'],
#  'UBE3A': ['PSMC4',
#   'PSMA5',
#   'GABRB3',
#   'GABRG3',
#   'HDAC1',
#   'PSMD3',
#   'UBE2L6',
#   'SF3B3',
#   'RBBP4',
#   'MAPK6',
#   'PSMC5',
#   'PSMD14',
#   'RAD23B',
#   'PSMB7',
#   'PTEN',
#   'NEURL4',
#   'PSMA7',
#   'SAP18',
#   'INADL',
#   'UBE2I',
#   'HERC2',
#   'MAGEL2',
#   'SUMO1',
#   'PSMD8',
#   'ENSG00000279392',
#   'PSME4',
#   'UBQLN1',
#   'ADRM1',
#   'ARHGEF15',
#   'PSMC1',
#   'DKC1',
#   'SIN3B',
#   'PSMD7',
#   'RNF2',
#   'USP7',
#   'UBE2E1',
#   'PSMA2',
#   'UFD1L',
#   'HSP90AA1',
#   'CTBP1',
#   'AR',
#   'NCOA3',
#   'TAT',
#   'HSPA4',
#   'MAP1S',
#   'PSMD11',
#   'ATP10A',
#   'PSMB2',
#   'TXNL1',
#   'TP53',
#   'MDM2',
#   'HDAC2',
#   'CUL2',
#   'ZNFX1',
#   'UBE2D3',
#   'CRB3',
#   'PSMC6',
#   'PSMB4',
#   'RAD23A',
#   'LAP3',
#   'MTOR',
#   'MPP5',
#   'CTNNB1',
#   'DLG3',
#   'SACS',
#   'PSMB6',
#   'PTGES3',
#   'SCRIB',
#   'RPS27A',
#   'WBP2',
#   'PSMD2',
#   'UBE2D2',
#   'ESR1',
#   'PSMD12',
#   'UBQLN2',
#   'TERT',
#   'UBC',
#   'ATP5L',
#   'ASPM',
#   'UBE2S',
#   'PSMC3',
#   'PSMA3',
#   'SAP30',
#   'ARNTL',
#   'PSMD6',
#   'SIN3A',
#   'MKRN3',
#   'FMR1',
#   'USP14',
#   'RBBP7',
#   'ATP10B',
#   'DLG1',
#   'YME1L1',
#   'UBE2E2',
#   'PSMB5',
#   'TCHP',
#   'TSC2',
#   'UNC45A',
#   'SLC9A6',
#   'ESR2',
#   'RCN2',
#   'UBE2N',
#   'LLGL2',
#   'UBE2L3',
#   'PRDX1',
#   'PSMD1',
#   'TSC1',
#   'HIF1AN',
#   'PSMD4',
#   'SNRPN',
#   'ATP6V0A2',
#   'LLGL1',
#   'PSMA4',
#   'LTN1',
#   'PSMD13',
#   'UCHL5',
#   'GABRA5',
#   'UBD',
#   'UBA1',
#   'MAGI1',
#   'PSMA6',
#   'NFX1',
#   'UBE2K',
#   'MECP2',
#   'PSMB3',
#   'UBE2D1',
#   'MYC',
#   'UBQLN4',
#   'NDN',
#   'NLGN3',
#   'PSMB1',
#   'PSMA1',
#   'CALM1',
#   'UBE2A',
#   'TUBGCP5',
#   'DLG2',
#   'PSMC2'],
#  'RBP2': ['RDH8',
#   'APOB',
#   'DHRS3',
#   'AKR1C1',
#   'DHRS9',
#   'APOA2',
#   'STRA6',
#   'CYP26A1',
#   'LIPC',
#   'GOT2',
#   'RARS',
#   'RDH11',
#   'PNLIP',
#   'AKR1C4',
#   'AKR1C3',
#   'RDH10',
#   'RBP3',
#   'AKR1B10',
#   'APOA4',
#   'APOA1',
#   'RDH12',
#   'DHRS4',
#   'LRAT',
#   'RBP4'],
#  'RBP1': ['GOT2',
#   'SDC3',
#   'RDH11',
#   'SDC2',
#   'RLBP1',
#   'RARS',
#   'STRA6',
#   'ALDH1A1',
#   'SDC1',
#   'CYP26A1',
#   'LIPC',
#   'TTR',
#   'APOE',
#   'RPE65',
#   'APOC2',
#   'DHRS9',
#   'GPC3',
#   'AKT1',
#   'SDR16C5',
#   'APOA2',
#   'RDH16',
#   'APOC3',
#   'APOB',
#   'RDH8',
#   'SDC4',
#   'GPC2',
#   'XDH',
#   'GPC5',
#   'GPC1',
#   'DHRS3',
#   'GPC6',
#   'HSPG2',
#   'RDH5',
#   'RBP4',
#   'AGRN',
#   'LRAT',
#   'SDR9C7',
#   'GPC4',
#   'ALDH1A3',
#   'ADH7',
#   'RBP3',
#   'RDH10',
#   'RDH12',
#   'ALDH1A2',
#   'DHRS4',
#   'APOA1',
#   'APOA4',
#   'HSD17B6',
#   'PNLIP'],
#  'PFKFB4': ['HK2',
#   'FBP2',
#   'PFKM',
#   'PFKL',
#   'PRKAG1',
#   'PRKAB1',
#   'PRKAB2',
#   'HK1',
#   'HK3',
#   'PFKFB1',
#   'MPI',
#   'PFKFB2',
#   'RFC3',
#   'PFKFB3',
#   'PFKP',
#   'HKDC1',
#   'PRKAA1',
#   'SMPD2',
#   'FBP1',
#   'MGAT1',
#   'PRKAG2',
#   'PRKAA2',
#   'C12orf5',
#   'PRKAG3'],
#  'HES1': ['ATRIP',
#   'STAT1',
#   'NOTCH1',
#   'CREBBP',
#   'NOTCH4',
#   'HEYL',
#   'SNW1',
#   'FANCB',
#   'C19orf40',
#   'TOP3A',
#   'HES6',
#   'RMI1',
#   'GAA',
#   'UBE2T',
#   'STAT3',
#   'FANCC',
#   'RFC3',
#   'JAK2',
#   'RAD9A',
#   'MAML2',
#   'NOTCH3',
#   'EP300',
#   'KAT2A',
#   'GATA1',
#   'FANCM',
#   'NEUROG3',
#   'BHLHE40',
#   'HES5',
#   'RAD17',
#   'FANCE',
#   'C17orf70',
#   'CHEK1',
#   'RFC2',
#   'SI',
#   'MAML1',
#   'JAG1',
#   'TLE4',
#   'RPA2',
#   'FANCA',
#   'RUNX3',
#   'PARP1',
#   'RFC4',
#   'TLE1',
#   'RB1',
#   'YY1',
#   'CAMK2D',
#   'FANCD2',
#   'MGAM',
#   'ATOH1',
#   'RUNX2',
#   'HUS1',
#   'TLE2',
#   'ATR',
#   'TOPBP1',
#   'KAT2B',
#   'HEY1',
#   'FANCI',
#   'RPA1',
#   'MYB',
#   'BLM',
#   'APITD1',
#   'RBPJ',
#   'FANCL',
#   'MAML3',
#   'TLE3',
#   'SIRT1',
#   'PTF1A',
#   'RFC5',
#   'HEY2',
#   'RAD1',
#   'ASCL1',
#   'MAMLD1',
#   'FANCG',
#   'FANCF',
#   'STRA13',
#   'NOTCH2'],
#  'GNAT1': ['RPE65',
#   'RAC2',
#   'LRIT3',
#   'OPRM1',
#   'CNGB3',
#   'PDCL',
#   'GNG13',
#   'GNAI2',
#   'GNA11',
#   'RCVRN',
#   'GNG8',
#   'NR2E3',
#   'GNAI1',
#   'GNA15',
#   'PDE6C',
#   'PDE6A',
#   'GNG5',
#   'GNGT2',
#   'GNAI3',
#   'LRRK2',
#   'GNAO1',
#   'NRL',
#   'GNA13',
#   'GNGT1',
#   'GNG11',
#   'CNGB1',
#   'GNG4',
#   'GNG12',
#   'OPN1LW',
#   'GNAQ',
#   'GNAZ',
#   'RAC3',
#   'PDE6B',
#   'ROCK2',
#   'METAP1',
#   'PDC',
#   'GNB2',
#   'ROCK1',
#   'GNA14',
#   'PDE6G',
#   'OPN4',
#   'GNB1',
#   'GNA12',
#   'CNGA1',
#   'DPYSL2',
#   'GNAL',
#   'OPN3',
#   'NMT2',
#   'SAG',
#   'OPN1SW',
#   'PLCB1',
#   'UNC119B',
#   'RGS9',
#   'GNB4',
#   'GNG10',
#   'RGS9BP',
#   'GNG3',
#   'RGR',
#   'CNGA3',
#   'GNB3',
#   'PDYN',
#   'ITPR2',
#   'OPN5',
#   'RRH',
#   'RHO',
#   'NMT1',
#   'METAP2',
#   'GRK1',
#   'PLCB3',
#   'GNAT2',
#   'PLCB2',
#   'GNAT3',
#   'POMC',
#   'ITPR1',
#   'GNAS',
#   'RGS11',
#   'CABP4',
#   'CRX',
#   'SLC24A1',
#   'NYX',
#   'GNB5',
#   'GNG2',
#   'GNG7',
#   'LRAT',
#   'ITPR3',
#   'PLCB4'],
#  'TUSC2': ['BCAS4', 'EBLN2', 'AP1S1', 'SUFU', 'FANCC'],
#  ...}

# %%
global_graph.keys()
# Out:
# dict_keys(['nodes', 'ARF5', 'M6PR', 'FKBP4', 'CYP26B1', 'NDUFAF7', 'FUCA2', 'HS3ST1', 'SEMA3F', 'CFTR', 'CYP51A1', 'USP28', 'SLC7A2', 'PDK4', 'USH1C', 'RALA', 'BAIAP2L1', 'CACNG3', 'TMEM132A', 'DVL2', 'RPAP3', 'SKAP2', 'PRSS21', 'HOXA11', 'CX3CL1', 'TRAPPC6A', 'WDR54', 'SPATA20', 'RHBDD2', 'TSR3', 'OSBPL7', 'YBX2', 'ITGA3', 'KRT33A', 'TFAP2D', 'CRY1', 'PGLYRP1', 'STARD3NL', 'CAMK1G', 'CD74', 'FAM76A', 'CPA1', 'SYPL1', 'RANBP9', 'CD4', 'TSPAN9', 'QPCTL', 'PPP5C', 'UBR7', 'MAP4K5', 'INMT', 'ERCC1', 'GPRC5A', 'HEBP1', 'COX15', 'MS4A12', 'RGPD5', 'XYLT2', 'SCTR', 'RALBP1', 'PSD', 'SYT13', 'SLC7A9', 'RTFDC1', 'RB1CC1', 'AKAP11', 'PIGQ', 'CDH17', 'B4GALT7', 'FAM13B', 'CHPF2', 'LRRC7', 'GABARAPL2', 'MYOC', 'FAM136A', 'OTC', 'TTC17', 'HOXC8', 'MRI1', 'BOD1L1', 'TARBP1', 'RTN4R', 'PSMA4', 'ZPBP', 'LCP2', 'DCN', 'TNFRSF17', 'MRPS10', 'GRN', 'THAP3', 'VAMP3', 'UTS2', 'RCN1', 'RFC2', 'PPP1R3F', 'KIAA2022', 'ARHGEF5', 'NFE2L3', 'TLL1', 'NNAT', 'CBLN4', 'CLDN11', 'FAM168A', 'RELT', 'PKP2', 'YIPF1', 'ADCK2', 'INPP4A', 'SLC2A3', 'STYK1', 'GNA11', 'CREB3L3', 'HDAC7', 'MRPS35', 'APPBP2', 'ISOC2', 'CD22', 'GSC2', 'KCNQ1', 'TRPM5', 'TRIB2', 'OTUD5', 'GPKOW', 'AQR', 'ST6GALNAC1', 'LMCD1', 'PSMC4', 'CAMKK1', 'ACAP1', 'DERL2', 'NOX3', 'KDM4B', 'ICAM3', 'CTTNBP2', 'ACTL6B', 'KIF22', 'PRSS22', 'CEACAM1', 'YTHDC2', 'TMEM161A', 'FOXJ2', 'TNFRSF1A', 'GOLGA5', 'CELSR3', 'PPP2R5B', 'PYGM', 'BCL3', 'PIGB', 'PDZD4', 'PRLH', 'FSTL3', 'EPHA8', 'TRIP13', 'VASH1', 'KRT14', 'KRT20', 'SPP2', 'HSD17B10', 'FGF4', 'ST6GAL1', 'TIMM21', 'BPIFB2', 'REXO1', 'MKRN2', 'GPATCH1', 'KEAP1', 'P2RY10', 'TNS1', 'NGFR', 'NTN1', 'ISOC1', 'TRO', 'MNT', 'LAPTM4A', 'ADAM7', 'ASNS', 'PTPN18', 'DRD4', 'SCT', 'STK10', 'TBX21', 'MRPS34', 'CA12', 'MAP2K5', 'C12orf5', 'FGF20', 'MTMR7', 'CPB2', 'FAM107B', 'CDK13', 'TSPAN32', 'TRAM2', 'CLDN18', 'ROPN1', 'NDUFB4', 'HEATR6', 'ERLEC1', 'CLIC5', 'TMEM131', 'TMEM38A', 'ACTR6', 'FAP', 'DMRT3', 'GAL3ST2', 'UHRF1BP1', 'OSTM1', 'IMPG2', 'SLC13A1', 'HSPB11', 'STRADB', 'PLOD1', 'OXCT1', 'ZNF416', 'KIAA1467', 'PILRA', 'RRN3', 'MOGAT2', 'AQP2', 'DIMT1', 'EIF2AK1', 'NME8', 'EPDR1', 'MRPL28', 'HBQ1', 'CEACAM6', 'RBM22', 'HSD17B2', 'ZW10', 'ITGB4', 'PPP1R15A', 'TRIP6', 'ADAM11', 'SLC22A4', 'CETP', 'MT3', 'TFAP2C', 'SULT2B1', 'EPS8L1', 'REM1', 'PDRG1', 'PPP1R13B', 'TGM6', 'RALGAPA2', 'ESF1', 'SIRT4', 'TRMT6', 'UQCRC1', 'GMIP', 'LAG3', 'MLF2', 'OTUB2', 'TFAP4', 'PDCD7', 'SPG21', 'CHRD', 'THPO', 'GNPTG', 'GOLGA3', 'EFNB1', 'GLG1', 'DLL3', 'NAT14', 'AASDH', 'DLD', 'ABCC6', 'CMTM6', 'MYO15A', 'APOH', 'SPAG7', 'CCDC80', 'HAUS4', 'CEBPE', 'OSGEP', 'G2E3', 'TGM1', 'TBX15', 'TEKT2', 'UNC13D', 'XYLB', 'OR1I1', 'ADH1A', 'KRT23', 'CDC6', 'AAAS', 'CBX5', 'KLHL20', 'FMO2', 'DHPS', 'RAB26', 'PSMD5', 'NANS', 'SEMA4G', 'TPSD1', 'GSTA3', 'MAPK13', 'TMEM14A', 'PRRT1', 'ZNF184', 'VCL', 'SIRT1', 'TGFBR3', 'TMED1', 'MZF1', 'OCEL1', 'PSMD8', 'STX1B', 'EFNA2', 'ATP5D', 'FGF22', 'SMIM24', 'NDUFB7', 'TECR', 'TIMM13', 'CDC34', 'MISP', 'GADD45B', 'MADCAM1', 'MAPK12', 'SERPIND1', 'SNAP29', 'LZTR1', 'THAP7', 'MMP11', 'MIF', 'DDTL', 'OSM', 'SF3A1', 'USP18', 'SEC14L3', 'SNRPD3', 'MAPK1', 'TCN2', 'CRYBB3', 'MORC2', 'SLC25A1', 'PLA2G3', 'PDXP', 'ASPHD2', 'LGALS1', 'PIK3IP1', 'SRRD', 'CRYBB1', 'ANKRD54', 'MICALL1', 'CENPM', 'DMC1', 'HSCB', 'TOMM22', 'RTDR1', 'XBP1', 'RTCB', 'JOSD1', 'GTPBP1', 'DNAL4', 'C22orf31', 'MIOX', 'RHBDD3', 'APOBEC3D', 'RASL10A', 'HMGXB4', 'BIK', 'HMOX1', 'NIPSNAP1', 'MCM5', 'ARSA', 'RASD2', 'TTLL12', 'CBX7', 'ACR', 'CABP7', 'TAB1', 'PNPLA5', 'PNPLA3', 'MYH9', 'TXN2', 'EIF3D', 'PVALB', 'UPK3A', 'FAM118A', 'ST13', 'IL2RB', 'RBX1', 'L3MBTL2', 'CHADL', 'PHF5A', 'ACO2', 'PMM1', 'CERK', 'BRD1', 'ZBED4', 'HDAC10', 'RIPK3', 'PAPOLA', 'NID2', 'SNAPC1', 'SUPT16H', 'FKBP3', 'CTSG', 'GZMH', 'GZMB', 'AP4S1', 'POLE2', 'SOS2', 'PYGL', 'GNPNAT1', 'CNIH1', 'CGRRF1', 'ATP6V1D', 'PLEK2', 'PIGH', 'PSMA3', 'GSTZ1', 'TMED8', 'SAMD15', 'AHSA1', 'SPTLC2', 'RIN3', 'ALKBH1', 'CHGA', 'DHRS7', 'SIX4', 'SLC10A1', 'EIF5', 'ZFYVE21', 'MTHFD1', 'BDKRB1', 'VRK1', 'APEX1', 'PABPN1', 'EFS', 'CINP', 'P ...

# %%
global_graph.values()
# Out:
# dict_values([{}, ['ACAP2', 'CD59', 'RAB1A', 'INS', 'TMED3', 'COPE', 'ACAP1', 'COPZ1', 'COPZ2', 'ANK1', 'EXOC7', 'ARFGAP3', 'ARF1', 'COPG1', 'ARFIP1', 'COPB2', 'CD55', 'SPTBN2', 'KDELR1', 'ARCN1', 'SURF4', 'IQSEC1', 'KDELR2', 'GORAB', 'COPG2', 'GGA3', 'GIT2', 'RABAC1', 'ARFIP2', 'ANK3', 'SPTB', 'TMED2', 'USO1', 'RAB28', 'SPTAN1', 'SPTBN5', 'RAB1B', 'GGA1', 'SPTBN4', 'YKT6', 'SPTBN1', 'TMED7', 'ASAP1', 'ARF3', 'FOLR1', 'GBF1', 'ARFGAP2', 'RAB11FIP3', 'SEC22B', 'GCC1', 'CYTH1', 'AGAP1', 'ASAP2', 'BET1', 'ARFGAP1', 'COPA', 'KDELR3', 'SPTA1', 'ARF4', 'TMED10', 'RAB11A', 'TMED9', 'RAB11FIP4', 'COPB1', 'ANK2', 'CYTH3'], ['AP2M1', 'ARF1', 'NSF', 'AP1S2', 'VTI1A', 'PSAP', 'IGF2R', 'AP1B1', 'GLA', 'EEA1', 'SORT1', 'GZMB', 'RAB5A', 'NAPG', 'AP1S3', 'TGOLN2', 'RAB7B', 'VAMP7', 'VAMP8', 'CTSW', 'AP2B1', 'RAB9A', 'VPS53', 'IDUA', 'LAMP1', 'VAMP4', 'RAB7A', 'NAGA', 'AP2A2', 'TFRC', 'VPS51', 'GNS', 'SCARB2', 'DNAJC6', 'CLTA', 'TXNDC5', 'GGA1', 'CTSB', 'GCC2', 'CLTC', 'DNASE2', 'VAMP3', 'VPS52', 'AP2S1', 'RAB9B', 'CTSD', 'IGF2', 'VPS54', 'ZFPL1', 'DNM2', 'WIPI1', 'NAPB', 'AP2A1', 'AP1M1', 'VAMP2', 'STX16', 'REN', 'GGA3', 'PLIN3', 'CTSZ', 'GGA2', 'OS9', 'SH3GL2', 'AP1G1', 'KIF13A', 'AP1M2', 'HSPA8', 'KIAA1468', 'ARRB1', 'ERLEC1', 'GOLGA2', 'CTSF', 'RABEPK', 'RHOBTB3', 'AP1S1', 'STX10', 'NAPA', 'SGSH'], ['TAPBPL', 'HSPA1B', 'IRF4', 'PWP1', 'DYNLL2', 'SUGT1', 'HSPA2', 'MAPK1', 'BCL2A1', 'ACTR10', 'NUP62', 'CACYBP', 'GNB2L1', 'PIK3C2A', 'GMPR2', 'DCAF11', 'DNAJB1', 'S100A6', 'MYOF', 'HSP90AB1', 'HSPH1', 'IFIT3', 'NRIP2', 'SERPINB2', 'AR', 'HSP90AA1', 'MAPK3', 'DCTN6', 'CDK5', 'CDC37', 'GLMN', 'CAPZA2', 'GMPR', 'HSPA4', 'PPP5C', 'CAPZA3', 'TP53', 'CRYL1', 'POSTN', 'DYNC1LI2', 'MTOR', 'DCTN2', 'HSF1', 'PPID', 'CAPZA1', 'DYNC1I1', 'TRPC3', 'MAPT', 'PTGES3', 'PDIA4', 'ACTR1A', 'SARS', 'DYNC1H1', 'ESR1', 'STIP1', 'ATOX1', 'PGR', 'CHORDC1', 'ECI2', 'CDC37L1', 'CLCA1', 'AHSA1', 'S100A2', 'DCTN5', 'HSPA1A', 'ATP1B3', 'HSPA8', 'ESR2', 'DCTN1', 'DCTN3', 'FKBP5', 'NR3C2', 'NR3C1', 'AP4M1', 'DCTN4', 'DYNC1I2', 'CAPZB', 'S100A1', 'AGO2', 'DYNLL1', 'PIN1', 'DYNC1LI1', 'TRPC1', 'HSPA1L', 'PHYH', 'PHLPP1'], ['STRA6', 'CYP26C1', 'CYP2S1', 'UGT1A7', 'UGT1A5', 'CYP2C8', 'RARS', 'CYP2A6', 'CYP2C9', 'UGT2B11', 'UGT2B4', 'UGT2B7', 'UGT2B15', 'UGT1A6', 'UGT1A3', 'CYP3A5', 'CYP2B6', 'CRABP1', 'UGT2A2', 'UGT2B28', 'UGT2B10', 'ALDH1A2', 'CYP1A2', 'ALDH1A1', 'NANOS2', 'CYP26A1', 'STRA8', 'UGT1A4', 'UGT1A10', 'AOX1', 'UGT1A9', 'UGT1A1', 'ALDH1A3', 'UGT1A8', 'UGT2B17', 'CRABP2', 'CYP3A4', 'CYP1B1', 'CYP3A7', 'RDH10', 'CYP4A11', 'CYP4A22', 'CYP2C18', 'UGT2A3', 'CYP1A1'], ['METTL10', 'NDUFA6', 'TRMT11', 'RSAD1', 'NDUFB2', 'METTL20', 'NDUFA3', 'NUBPL', 'COX6C', 'NDUFAF4', 'ECSIT', 'TFB2M', 'NDUFAF6', 'TMEM126B', 'NDUFS8', 'NDUFB11', 'NDUFAF5', 'MT-ND2', 'NDUFAF2', 'NDUFA9', 'PPOX', 'NDUFS2', 'MT-ND4', 'NDUFS7', 'NDUFB8', 'MT-ND6', 'NDUFA8', 'UBE3B', 'TIMMDC1', 'NDUFB9', 'FOXRED1', 'NDUFA2', 'NDUFAB1', 'MT-ND1', 'NSUN3', 'NDUFA11', 'NDUFC1', 'NDUFA7', 'METTL13', 'NDUFS3', 'NDUFB7', 'ACAD9', 'MT-ND3', 'MT-ND5', 'NDUFB1', 'MTRF1L', 'NDUFA10', 'NDUFA13', 'NDUFB5', 'NDUFA1', 'NDUFAF1', 'MTRF1', 'COA5', 'NDUFC2', 'NDUFB6', 'NDUFB3', 'NDUFB4', 'NDUFB10', 'NDUFAF3', 'NDUFA5'], ['KRT1', 'TXLNB', 'CRIP3', 'KRT16', 'GLB1', 'HIVEP2', 'FUK', 'PLG', 'HEXB', 'ADAT2', 'SNX9', 'TGM1', 'FPGT', 'NAGA', 'FUCA1', 'HSD11B1', 'SLC22A13', 'SLC22A23', 'HEXA', 'NAGLU', 'CD99L2', 'GLA'], ['SDC4', 'GPC5', 'GPC1', 'GPC2', 'HS2ST1', 'HS6ST3', 'HS6ST2', 'GPC6', 'RAB28', 'GPC3', 'GLCE', 'SDC1', 'GCNT3', 'SDC3', 'SERPINC1', 'SDC2', 'HS6ST1', 'EXT1', 'A4GNT', 'FUT10', 'ENSG00000267561', 'UST', 'PLEKHG1', 'AGRN', 'GPC4', 'GCNT4', 'EXT2', 'ARSG', 'HSPG2', 'EXTL3', 'TNS4'], ['PLXND1', 'PLXNB3', 'EPHA6', 'PLXNC1', 'VEGFA', 'PLXNB1', 'PLXNB2', 'EPHA1', 'ROBO2', 'NTN1', 'SLIT3', 'PLXNA3', 'PLXNA1', 'NRP1', 'NRP2'], ['ERLIN2', 'PSMD2', 'PRKAR1A', 'GUCA2A', 'ERLIN1', 'RPS27A', 'SLC9A2', 'PSMB6', 'UBE2V1', 'STX16', 'ANO2', 'GOPC', 'PSMC3', 'PSMB10', 'HBB', 'PRSS58', 'DLG4', 'SLC4A4', 'LPAR2', 'BEST2', 'GUCY2C', 'UBC', 'K ...

# %%
drug_dicts = {}
with open('../codes/BFregNN-Cox-for-pyroptosis-in-TNBC/data/9_drug_targets_1.0_revised.tsv') as f:
    for line in f.readlines():
        line = line.split('\n')[0].split('\t')
        drug_dicts[line[0]]=line[1:]

# %%
drug_dicts.keys()
# Out:
# dict_keys(['methotrexate', 'noscapine', 'methylprednisolone', 'podophyllotoxin', 'celastrol', 'daunorubicin', 'estramustine', 'isotretinoin', 'tamoxifen', 'wortmannin', 'oxidopamine', 'mitoxantrone', 'tanespimycin', 'emodin', 'vinorelbine', 'irinotecan', '7-hydroxystaurosporine', 'kenpaullone', 'gambogic acid', 'vorinostat', 'entinostat', 'belinostat', 'cyclopamine', 'nelfinavir', 'olaparib', 'shogaol', 'trametinib', 'idelalisib', 'navitoclax', 'panobinostat', 'ibrutinib', 'dabrafenib', 'ipatasertib', 'ceritinib', 'dactolisib'])

# %%
import networkx as nx
import numpy as np
from copy import deepcopy
from sklearn import preprocessing
import random  
import torch
import csv

# %%
def generate_network_architecture(graph_dicts, drug_gene_dicts, key1, key2, thres):

    def count_degree(graph_dicts,gene_list):
        degree_list = []
        return_graph_dicts = {}
        return_graph_dicts['edges'] = []
        for idx, g in enumerate(gene_list):
            degree_list.append(0)
            if g in graph_dicts:
                for end_nodes in graph_dicts[g]:
                    if end_nodes in gene_list and [idx,gene_list.index(end_nodes)] not in return_graph_dicts['edges']:
                        return_graph_dicts['edges'].append([idx,gene_list.index(end_nodes)]) 
                        degree_list[idx]+=1
        return degree_list


    def select_subgraph(graph_dicts,gene_list):
        gene_list = list(set(gene_list))
        gene_list.sort()
        return_graph_dicts = {}
        return_graph_dicts['nodes'] = []
        return_graph_dicts['nodes_name'] = []
        return_graph_dicts['edges'] = []
        for idx, g in enumerate(gene_list):
            return_graph_dicts['nodes'].append(idx)
            return_graph_dicts['nodes_name'].append(g)
            if g in graph_dicts:
                for end_nodes in graph_dicts[g]:
                    if end_nodes in gene_list and [idx,gene_list.index(end_nodes)] not in return_graph_dicts['edges']:
                        return_graph_dicts['edges'].append([idx,gene_list.index(end_nodes)]) 
                        
            return_graph_dicts['edges'].append([idx,idx])
        # return_graph_dicts['edges']=list(set(return_graph_dicts['edges']))
        return return_graph_dicts


    def trans_dicts2graph(graph_dicts):
        """
            将字典形式的图数据转换为NetworkX图对象。
            参数:
                graph_dicts (dict): 字典形式的图数据，键表示节点，
                值表示与该节点相连的节点列表。

            返回值:
                 G (networkx.Graph): 转换后的NetworkX图对象，包含所有节点和边。
        """
        G = nx.Graph()
        # 遍历字典中的每个节点及其连接的节点列表
        for key in graph_dicts.keys():
            for k in graph_dicts[key]:
                 # 将节点对作为边添加到图中
                G.add_edges_from([(key,k)])
        return G
        

    def shortest_path(G,source,target):
        try:
            num = nx.shortest_path_length(G, source, target)
        except: 
            return float('inf')
        return num
    

    def trans_layer(Gs, source_list, target_list):
        affin_graph = []
        removed_target = deepcopy(target_list)
        removed_source = []
        for idx_s, g_s in enumerate(source_list):
            marks_gene = {}
            min_num = float('inf')
            for idx, g_t in enumerate(target_list):
                num = shortest_path(Gs,g_s,g_t)
                if num not in marks_gene:
                    marks_gene[num] = []
                marks_gene[num].append(idx)
                if num > thres:
                    if g_t in removed_target:
                        removed_target.remove(g_t)
                if num < min_num:
                    min_num = num
            if min_num > thres:
                removed_source.append(g_s)
                continue
            for key in marks_gene.keys():
                # print(key,marks_gene[key])
                if key <= thres:
                    for g in marks_gene[key]:
                        affin_graph.append([idx_s,g])
        return removed_source, removed_target, np.array(affin_graph)
    

    def max_connect(basic_layer,second_layer,transfer_layer):
        G = nx.Graph()
        removed = []
        basic_lens = len(basic_layer['nodes'])
        for e in basic_layer['edges']:
            G.add_edge(e[0], e[1])
        for e in second_layer['edges']:
            G.add_edge(e[0] + basic_lens, e[1] + basic_lens)
        for e in transfer_layer:
            G.add_edge(e[0], e[1] + basic_lens)

        largest_graph = nx.connected_components(G)
        nodes = []
        for n in second_layer['nodes']:
            nodes.append(n + basic_lens)
        id_list = []
        for c in largest_graph:
            for n in c:
                if n in nodes:
                    id_list.append(1)
                else:
                    id_list.append(0)
        for idx, c in largest_graph:
            for n in c:
                if id_list[idx] == 0:
                    if n in basic_layer['nodes']:
                        removed.append(basic_layer['nodes_name'][n])
        return removed
    

    Gs = trans_dicts2graph(graph_dicts)

    focus_genes_list = []
    with open('../codes/BFregNN-Cox-for-pyroptosis-in-TNBC/data/gene_pyroptosis_9.txt') as f:
        for line in f.readlines():
            focus_genes_list.append(line.split()[0])

    first_layer_gene = drug_gene_dicts[key1] + drug_gene_dicts[key2]
    first_layer_gene.sort()  
    removed_s, removed_t, transfer_layer = trans_layer(Gs, first_layer_gene, focus_genes_list)
    second_layer_graph = select_subgraph(graph_dicts, focus_genes_list)


    drug_list = drug_gene_dicts[key1] + drug_gene_dicts[key2]
    drug_list.sort()  

    degree_list = count_degree(graph_dicts,drug_list)
    drug_list = [d for idx, d in enumerate(drug_list) if not (d in removed_s and degree_list[idx]==0)]  


    basic_layer_graph = select_subgraph(graph_dicts, drug_list)
    first_layer_gene = basic_layer_graph['nodes_name']
    removed = max_connect(basic_layer_graph, second_layer_graph, transfer_layer)
    removed_s, removed_t, transfer_layer = trans_layer(Gs, first_layer_gene, focus_genes_list)
    removed_all = removed_s + removed


    drug_list = [d for idx, d in enumerate(drug_list) if not d in removed_all]  
    basic_layer_graph = select_subgraph(graph_dicts, drug_list)
    first_layer_gene = basic_layer_graph['nodes_name']
    removed_s, removed_t, transfer_layer = trans_layer(Gs, first_layer_gene, focus_genes_list)

    return basic_layer_graph, transfer_layer, second_layer_graph

# %%
basic_layer, transfer_layer, second_layer = generate_network_architecture(global_graph, drug_dicts, "methotrexate", "noscapine", 2)

# %%
transfer_layer = np.array(transfer_layer).T
basic_layer_adj = np.array(basic_layer['edges']).T
second_layer_adj = np.array(second_layer['edges']).T

# %%
def read_patient_info(gene_list):
    csv_reader = csv.reader(open("../data/tnbc2022_448s_gene_tpm_matrix.csv"))
    first_line = True
    X_index = {}
    for line in csv_reader:
        if first_line:
            temp_id_list = line[1:]
            first_line = False
        else:
            gene_name = line[0].strip('\n').strip(' ')
            i = gene_name.find('|')
            gene_name = gene_name[i+1:]
            if gene_name in gene_list:
                X_index[gene_name] = line[1:]

    X_all = []
    for gene_name in gene_list:
        X_all.append(X_index[gene_name])
    X_all=np.array(X_all)
    X_all = X_all.transpose()

    x_sample_id_list = []
    for sample_id in temp_id_list:
        pos = sample_id.find("_rep")
        if pos>0:
            sample_id = sample_id[0:pos]
        x_sample_id_list.append(sample_id)
    
    gene_index = gene_list

    csv_reader = csv.reader(open("../codes/BFregNN-Cox-for-pyroptosis-in-TNBC/data/FUSCCTNBC_info.csv"))
    first_line = True
    y_tumor = {} # 1-tumor 0-normal
    y_subtypes = {} # 1-LAR 2-MES 3-BLIS 4-IM  0-Normal
    for line in csv_reader:
        if first_line:
            first_line = False
        else:
            sample_id = line[1].strip('\n').strip(' ')
            if line[2] == "tumor":
                y_tumor[sample_id] = 1
            elif line[2] == "normal":
                y_tumor[sample_id] = 0
            
            if line[3] == "LAR":
                y_subtypes[sample_id] = 1
            elif line[3] == "MES":
                y_subtypes[sample_id] = 2
            elif line[3] == "BLIS":
                y_subtypes[sample_id] = 3
            elif line[3] == "IM":
                y_subtypes[sample_id] = 4
            elif line[3] == "Normal":
                y_subtypes[sample_id] = 0

    first_line = True
    pos_needed = ["PATIENT_ID", "RFS_STATUS", "RFS_TIME_DAYS", "RFS_TIME_MONTHS"]
    pos_id_needed = []
    y_survival = {}
    with open("../codes/BFregNN-Cox-for-pyroptosis-in-TNBC/data/fuscctnbc_clinical_patient.txt","r") as f:
        for line in f:
            line = line.strip(' ').strip('\n')
            items = line.split("\t")
            if first_line:
                i = 0
                for item in items:
                    if item in pos_needed:
                        pos_id_needed.append(i)
                    i = i + 1
                first_line = False
            else:
                s_id = items[pos_id_needed[0]]
                if s_id in y_subtypes:
                    if items[pos_id_needed[1]]=="0":
                        y_survival[s_id]=(False, items[pos_id_needed[2]])
                    if items[pos_id_needed[1]]=="1":
                        y_survival[s_id]=(True, items[pos_id_needed[2]])

    x_data = []
    index = []
    y_data_label = []
    y_data_time = []
    for i, sample_id in enumerate(x_sample_id_list):
        if y_subtypes[sample_id] != 0:
            x_data.append(X_all[i])
            index.append(sample_id)
            y_data_label.append(y_survival[sample_id][0])
            y_data_time.append(float(y_survival[sample_id][1]))
    
    x_data = np.array(x_data)
    y_data_label = np.expand_dims(np.array(y_data_label),axis=0)
    y_data_time = np.expand_dims(np.array(y_data_time),axis=0)
    y_data = np.concatenate((y_data_label,y_data_time),axis=0).T
    return x_data, y_data

# %%
X, y = read_patient_info(basic_layer['nodes_name'])

# %%
X
# Out:
# array([['0.0', '0.0', '8.353178999999999', ..., '0.0', '3.102891',
#         '19.710913'],
#        ['0.0', '0.0', '11.096731', ..., '0.0', '3.974506', '4.967147'],
#        ['0.0', '0.0', '3.858206', ..., '0.0', '5.542974', '10.577196'],
#        ...,
#        ['0.0', '0.0', '10.56947', ..., '0.0', '4.962445', '20.389592'],
#        ['0.0', '0.0', '12.782771', ..., '0.0', '6.788181', '14.925481'],
#        ['0.0', '0.0', '16.148946', ..., '0.0', '9.456936',
#         '22.446747000000002']], dtype='<U19')

# %%
y
# Out:
# array([[0.000e+00, 1.549e+03],
#        [0.000e+00, 1.059e+03],
#        [0.000e+00, 2.838e+03],
#        [0.000e+00, 1.193e+03],
#        [0.000e+00, 2.654e+03],
#        [0.000e+00, 1.823e+03],
#        [0.000e+00, 1.164e+03],
#        [0.000e+00, 2.404e+03],
#        [0.000e+00, 1.934e+03],
#        [0.000e+00, 1.362e+03],
#        [1.000e+00, 4.300e+01],
#        [0.000e+00, 1.360e+03],
#        [1.000e+00, 1.130e+03],
#        [0.000e+00, 1.038e+03],
#        [0.000e+00, 1.038e+03],
#        [0.000e+00, 1.092e+03],
#        [0.000e+00, 1.871e+03],
#        [0.000e+00, 1.577e+03],
#        [0.000e+00, 3.190e+02],
#        [0.000e+00, 3.520e+02],
#        [0.000e+00, 2.475e+03],
#        [0.000e+00, 2.404e+03],
#        [0.000e+00, 1.815e+03],
#        [1.000e+00, 2.003e+03],
#        [0.000e+00, 1.510e+03],
#        [0.000e+00, 1.331e+03],
#        [0.000e+00, 1.785e+03],
#        [0.000e+00, 1.403e+03],
#        [0.000e+00, 1.052e+03],
#        [0.000e+00, 1.788e+03],
#        [0.000e+00, 1.015e+03],
#        [0.000e+00, 1.550e+02],
#        [0.000e+00, 2.000e+01],
#        [1.000e+00, 1.050e+03],
#        [0.000e+00, 1.852e+03],
#        [0.000e+00, 8.140e+02],
#        [1.000e+00, 9.400e+01],
#        [0.000e+00, 1.906e+03],
#        [0.000e+00, 1.233e+03],
#        [0.000e+00, 1.057e+03],
#        [0.000e+00, 1.568e+03],
#        [0.000e+00, 1.213e+03],
#        [0.000e+00, 1.256e+03],
#        [0.000e+00, 7.790e+02],
#        [0.000e+00, 1.334e+03],
#        [0.000e+00, 2.017e+03],
#        [0.000e+00, 2.409e+03],
#        [0.000e+00, 2.046e+03],
#        [0.000e+00, 1.147e+03],
#        [0.000e+00, 2.577e+03],
#        [0.000e+00, 1.843e+03],
#        [0.000e+00, 1.788e+03],
#        [0.000e+00, 3.320e+03],
#        [1.000e+00, 1.609e+03],
#        [0.000e+00, 9.060e+02],
#        [0.000e+00, 1.201e+03],
#        [0.000e+00, 2.801e+03],
#        [0.000e+00, 2.165e+03],
#        [0.000e+00, 1.701e+03],
#        [0.000e+00, 1.448e+03],
#        [0.000e+00, 1.809e+03],
#        [0.000e+00, 1.053e+03],
#        [0.000e+00, 1.137e+03],
#        [0.000e+00, 1.875e+03],
#        [0.000e+00, 1.522e+03],
#        [0.000e+00, 2.344e+03],
#        [0.000e+00, 1.885e+03],
#        [0.000e+00, 2.225e+03],
#        [0.000e+00, 1.361e+03],
#        [0.000e+00, 2.117e+03],
#        [0.000e+00, 2.620e+03],
#        [0.000e+00, 1.479e+03],
#        [1.000e+00, 6.560e+02],
#        [0.000e+00, 1.642e+03],
#        [0.000e+00, 1.165e+03],
#        [0.000e+00, 1.856e+03],
#        [0.000e+00, 1.148e+03],
#        [1.000e+00, 3.970e+02],
#        [1.000e+00, 4.020e+02],
#        [0.000e+00, 1.186e+03],
#        [0.000e+00, 1.600e+01],
#        [0.000e+00, 1.060e+03],
#        [0.000e+00, 9.260e+02],
#        [0.000e+00, 1.449e+03],
#        [0.000e+00, 1.499e+03],
#        [0.000e+00, 0.000e+00],
#        [0.000e+00, 9.880e+02],
#        [0.000e+00, 7.210e+02],
#        [0.000e+00, 1.096e+03],
#        [0.000e+00, 2.613e+03],
#        [0.000e+00, 1.073e+03],
#        [0.000e+00, 1.121e+03],
#        [0.000e+00, 1.075e+03],
#        [0.000e+00, 1.890e+03],
#        [1.000e+00, 5.820e+02],
#        [0.000e+00, 1.254e+03],
#        [0.000e+00, 2.053e+03],
#        [0.000e+00, 1.864e+03],
#        [0.000e+00, 1.193e+03],
#        [0.000e+00, 1.552e+03],
#        [0.000e+00, 1.800e+03],
#        [0.000e+00, 1.039e+03],
#        [1.000e+00, 9.940e+02],
#        [0.000e+00, 1.046e+03],
#        [0.000e+00, 1.362e+03],
#        [0.000e+00, 1.654e+03],
#        [0.000e+00, 1.058e+03],
#        [1.000e+00, 1.031e+03],
#        [0.000e+00, 1.969e+03],
#        [0.000e+00, 2.232e+03],
#        [1.000e+00, 4.300e+02],
#        [0.000e+00, 1.466e+03],
#        [1.000e+00, 4.130e+02],
#        [0.000e+00, 1.159e+03],
#        [1.000e+00, 7.490e+02],
#        [0.000e+00, 2.374e+03],
#        [0.000e+00, 1.080e+03],
#        [0.000e+00, 1.235e+03],
#        [0.000e+00, 1.324e+03],
#        [1.000e+00, 7.940e+02],
#        [0.000e+00, 1.032e+03],
#        [0.000e+00, 1.061e+03],
#        [1.000e+00, 3.900e+02],
#        [0.000e+00, 1.396e+03],
#        [0.000e+00, 2.141e+03],
#        [0.000e+00, 1.277e+03],
#        [0.000e+00, 2.947e+03],
#        [0.000e+00, 1.010e+02],
#        [1.000e+00, 9.450e+02],
#        [1.000e+00, 1.306e+03],
#        [1.000e+00, 9.260e+02],
#        [0.000e+00, 1.747e+03],
#        [0.000e+00, 1.199e+03],
#        [0.000e+00, 1.439e+03],
#        [1.000e+00, 9.050e+02],
#        [0.000e+00, 4.170e+02],
#        [0.000e+00, 3.165e+03],
#        [0.000e+00, 2.468e+03],
#        [0.000e+00, 2.874e+03],
#        [1.000e+00, 2.820e+02],
#        [0.000e+00, 2.116e+03],
#        [0.000e+00, 1.040e+03],
#        [0.000e+00, 1.218e+03],
#        [0.000e+00, 1.831e+03],
#        [0.000e+00, 2.842e+03],
#        [0.000e+00, 2.443e+03],
#        [0.000e+00, 1.364e+03],
#        [0.000e+00, 1.189e+03],
#        [0.000e+00, 1.720e+03],
#        [0.000e+00, 8.860e+02],
#        [0.000e+00, 1.768e+03],
#        [1.000e+00, 6.480e+02],
#        [0.000e+00, 1.787e+03],
#        [0.000e+00, 1.532e+03],
#        [0.000e+00, 1.408e+03],
#        [0.000e+00, 2.000e+01],
#        [0.000e+00, 2.878e+03],
#        [0.000e+00, 2.865e+03],
#        [0.000e+00, 2.207e+03],
#        [0.000e+00, 7.260e+02],
#        [0.000e+00, 1.122e+03],
#        [0.000e+00, 2.137e+03],
#        [0.000e+00, 8.120e+02],
#        [0.000e+00, 1.170e+03],
#        [0.000e+00, 1.215e+03],
#        [0.000e+00, 1.129e+03],
#        [1.000e+00, 5.890e+02],
#        [1.000e+00, 2.590e+02],
#        [0.000e+00, 1.472e+03],
#        [0.000e+00, 1.795e+03],
#        [0.000e+00, 9.760e+02],
#        [0.000e+00, 2.061e+03],
#        [0.000e+00, 1.087e+03],
#        [0.000e+00, 1.359e+03],
#        [0.000e+00, 9.640e+02],
#        [0.000e+00, 9.580e+02],
#        [0.000e+00, 2.072e+03],
#        [0.000e+00, 1.007e+03],
#        [0.000e+00, 1.742e+03],
#        [0.000e+00, 2.039e+03],
#        [0.000e+00, 1.772e+03],
#        [0.000e+00, 1.080e+03],
#        [0.000e+00, 2.930e+02],
#        [0.000e+00, 2.650e+03],
#        [0.000e+00, 9.590e+02],
#        [0.000e+00, 1.226e+03],
#        [0.000e+00, 5.890e+02],
#        [0.000e+00, 1.359e+03],
#        [0.000e+00, 1.472e+03],
#        [0.000e+00, 2.088e+03],
#        [0.000e+00, 8.950e+02],
#        [0.000e+00, 1.183e+03],
#        [0.000e+00, 1.639e+03],
#        [0.000e+00, 9.480e+02],
#        [0.000e+00, 9.300e+02],
#        [1.000e+00, 6.300e+02],
#        [0.000e+00, 1.627e+03],
#        [0.000e+00, 1.700e+01],
#        [0.000e+00, 1.334e+03],
#        [0.000e+00, 1.600e+01],
#        [0.000e+00, 1.879e+03],
#        [0.000e+00, 1.332e+03],
#        [0.000e+00, 1.869e+03],
#        [0.000e+00, 1.057e+03],
#        [0.000e+00, 1.099e+03],
#        [0.000e+00, 2.570e+02],
#        [0.000e+00, 8.460e+02],
#        [0.000e+00, 6.990e+02],
#        [0.000e+00, 1.086e+03],
#        [1.000e+00, 3.830e+02],
#        [0.000e+00, 1.448e+03],
#        [1.000e+00, 5.890e+02],
#        [0.000e+00, 1.793e+03],
#        [0.000e+00, 1.137e+03],
#        [0.000e+00, 1.951e+03],
#        [0.000e+00, 1.219e+03],
#        [0.000e+00, 1.458e+03],
#        [1.000e+00, 8.120e+02],
#        [0.000e+00, 2.069e+03],
#        [0.000e+00, 1.033e+03],
#        [0.000e+00, 1.160e+03],
#        [0.000e+00, 1.500e+03],
#        [0.000e+00, 1.263e+03],
#        [0.000e+00, 1.173e+03],
#        [0.000e+00, 2.515e+03],
#        [0.000e+00, 1.905e+03],
#        [1.000e+00, 5.390e+02],
#        [0.000e+00, 1.592e+03],
#        [0.000e+00, 1.483e+03],
#        [0.000e+00, 2.144e+03],
#        [0.000e+00, 1.533e+03],
#        [0.000e+00, 1.005e+03],
#        [0.000e+00, 1.541e+03],
#        [1.000e+00, 1.044e+03],
#        [0.000e+00, 1.415e+03],
#        [1.000e+00, 1.850e+02],
#        [1.000e+00, 1.093e+03],
#        [0.000e+00, 1.046e+03],
#        [0.000e+00, 2.563e+03],
#        [0.000e+00, 1.526e+03],
#        [1.000e+00, 4.700e+02],
#        [0.000e+00, 1.758e+03],
#        [0.000e+00, 1.940e+03],
#        [0.000e+00, 1.994e+03],
#        [0.000e+00, 1.740e+03],
#        [0.000e+00, 2.164e+03],
#        [0.000e+00, 1.337e+03],
#        [0.000e+00, 2.090e+03],
#        [1.000e+00, 1.760e+02],
#        [0.000e+00, 1.186e+03],
#        [0.000e+00, 1.114e+03],
#        [0.000e+00, 2.388e+03],
#        [0.000e+00, 6.850e+02],
#        [0.000e+00, 1.238e+03],
#        [0.000e+00, 9.160e+02],
#        [1.000e+00, 8.900e+02],
#        [0.000e+00, 2.180e+03],
#        [0.000e+00, 9.270e+02],
#        [1.000e+00, 7.090e+02],
#        [0.000e+00, 1.147e+03],
#        [0.000e+00, 1.442e+03],
#        [0.000e+00, 1.277e+03],
#        [0.000e+00, 9.430e+02],
#        [0.000e+00, 1.370e+02],
#        [0.000e+00, 9.210e+02],
#        [0.000e+00, 1.634e+03],
#        [0.000e+00, 1.329e+03],
#        [1.000e+00, 2.860e+02],
#        [0.000e+00, 1.343e+03],
#        [1.000e+00, 3.740e+02],
#        [0.000e+00, 9.060e+02],
#        [0.000e+00, 1.271e+03],
#        [0.000e+00, 1.322e+03],
#        [0.000e+00, 1.723e+03],
#        [0.000e+00, 1.443e+03],
#        [1.000e+00, 2.590e+02],
#        [0.000e+00, 0.000e+00],
#        [0.000e+00, 1.523e+03],
#        [0.000e+00, 1.920e+03],
#        [0.000e+00, 1.546e+03],
#        [0.000e+00, 1.508e+03],
#        [1.000e+00, 1.031e+03],
#        [0.000e+00, 1.450e+03],
#        [0.000e+00, 1.320e+03],
#        [1.000e+00, 1.340e+02],
#        [1.000e+00, 5.250e+02],
#        [0.000e+00, 1.671e+03],
#        [0.000e+00, 1.930e+02],
#        [0.000e+00, 1.900e+03],
#        [1.000e+00, 3.450e+02],
#        [0.000e+00, 1.441e+03],
#        [0.000e+00, 1.639e+03],
#        [0.000e+00, 1.890e+03],
#        [0.000e+00, 1.411e+03],
#        [0.000e+00, 1.515e+03],
#        [0.000e+00, 1.467e+03],
#        [0.000e+00, 1.423e+03],
#        [0.000e+00, 9.500e+02],
#        [1.000e+00, 4.500e+02],
#        [0.000e+00, 1.449e+03],
#        [0.000e+00, 1.544e+03],
#        [0.000e+00, 2.276e+03],
#        [0.000e+00, 1.514e+03],
#        [0.000e+00, 1.332e+03],
#        [0.000e+00, 8.180e+02],
#        [0.000e+00, 1.051e+03],
#        [0.000e+00, 1.669e+03],
#        [0.000e+00, 1.644e+03],
#        [0.000e+00, 6.410e+02],
#        [0.000e+00, 1.522e+03],
#        [0.000e+00, 1.457e+03],
#        [0.000e+00, 1.158e+03],
#        [0.000e+00, 1.110e+03],
#        [0.000e+00, 2.144e+03],
#        [0.000e+00, 1.284e+03],
#        [0.000e+00, 1.281e+03],
#        [0.000e+00, 1.359e+03],
#        [0.000e+00, 2.409e+03],
#        [0.000e+00, 2.382e+03],
#        [0.000e+00, 7.160e+02],
#        [0.000e+00, 1.450e+03],
#        [0.000e+00, 2.038e+03],
#        [0.000e+00, 1.934e+03],
#        [0.000e+00, 1.791e+03],
#        [0.000e+00, 1.769e+03],
#        [0.000e+00, 1.774e+03],
#        [0.000e+00, 1.378e+03],
#        [0.000e+00, 1.780e+03],
#        [0.000e+00, 1.556e+03],
#        [0.000e+00, 1.661e+03],
#        [0.000e+00, 1.565e+03],
#        [0.000e+00, 1.421e+03],
#        [0.000e+00, 1.398e+03],
#        [0.000e+00, 1.474e+03],
#        [0.000e+00, 1.120e+03],
#        [0.000e+00, 1.375e+03],
#        [0.000e+00, 2.164e+03],
#        [0.000e+00, 1.958e+03],
#        [1.000e+00, 9.970e+02],
#        [0.000e+00, 1.375e+03],
#        [0.000e+00, 1.722e+03],
#        [0.000e+00, 1.765e+03],
#        [0.000e+00, 1.625e+03],
#        [0.000e+00, 1.740e+03],
#        [0.000e+00, 1.737e+03],
#        [1.000e+00, 6.150e+02],
#        [0.000e+00, 1.592e+03],
#        [0.000e+00, 1.648e+03],
#        [0.000e+00, 1.129e+03],
#        [0.000e+00, 1.440e+03],
#        [0.000e+00, 1.543e+03],
#        [0.000e+00, 1.374e+03],
#        [0.000e+00, 8.380e+02],
#        [1.000e+00, 1.137e+03],
#        [0.000e+00, 1.464e+03],
#        [0.000e+00, 1.467e+03],
#        [0.000e+00, 1.373e+03],
#        [1.000e+00, 3.570e+02],
#        [0.000e+00, 1.291e+03],
#        [0.000e+00, 1.353e+03]])
